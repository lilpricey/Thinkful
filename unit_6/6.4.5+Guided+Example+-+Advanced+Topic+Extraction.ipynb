# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Comparing LSA, LDA, and NNMF
#
# Now that you've been introduced to the logic behind these three topic extraction methods, we're going to try them out on the *Emma* corpus.  We'll be looking at interpretability, speed, and consistency across methods.  The goal is to identify common themes in *Emma* on a per-paragraph basis.  We won't be using pLSA as sklearn does not support it.
#
# To do this, we will:
#
# 1. Parse and process the data into a tf-idf matrix.
# 2. Fit LSA, LDA, and NNMF models with 5 topics each.
# 4. Extract the words that best describe each topic.
# 5. Examine the topic relationships for the words 'marriage', 'love', and 'Emma.'
#
# ## Generating the tfidf matrix

# %%
# Processing the data.

from nltk.corpus import gutenberg
import re
from sklearn.feature_extraction.text import TfidfVectorizer


#reading in the data, this time in the form of paragraphs
emma=gutenberg.paras('austen-emma.txt')
#processing
emma_paras=[]
for paragraph in emma:
    para=paragraph[0]
    #removing the double-dash from all words
    para=[re.sub(r'--','',word) for word in para]
    #Forming each paragraph into a string and adding it to the list of strings.
    emma_paras.append(' '.join(para))

# Creating the tf-idf matrix.
vectorizer = TfidfVectorizer(stop_words='english')
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)

# Getting the word list.
terms = vectorizer.get_feature_names()

# Number of topics.
ntopics=5

# Linking words to topics
def word_topic(tfidf,solution, wordlist):
    
    # Loading scores for each word on each topic/component.
    words_by_topic=tfidf.T * solution

    # Linking the loadings to the words in an easy-to-read way.
    components=pd.DataFrame(words_by_topic,index=wordlist)
    
    return components

# Extracts the top N words and their loadings for each topic.
def top_words(components, n_top_words):
    n_topics = range(components.shape[1])
    index= np.repeat(n_topics, n_top_words, axis=0)
    topwords=pd.Series(index=index)
    for column in range(components.shape[1]):
        # Sort the column so that highest loadings are at the top.
        sortedwords=components.iloc[:,column].sort_values(ascending=False)
        # Choose the N highest loadings.
        chosen=sortedwords[:n_top_words]
        # Combine loading and index into a string.
        chosenlist=chosen.index +" "+round(chosen,2).map(str) 
        topwords.loc[column]=chosenlist
    return(topwords)

# Number of words to look at for each topic.
n_top_words = 10

# %% [markdown]
# In addition to creating the tfidf matrix, there are two convenience functions that will help keep the code tidy when comparing models.  The first provides a list of the words that are paired with each topic.  The second gives us the best words for each topic so we can compare across methods.
#
# ## Fitting the three topic extraction models

# %%
# LSA

from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer

svd= TruncatedSVD(ntopics)
lsa = make_pipeline(svd, Normalizer(copy=False))
emma_paras_lsa = lsa.fit_transform(emma_paras_tfidf)

components_lsa = word_topic(emma_paras_tfidf, emma_paras_lsa, terms)

topwords=pd.DataFrame()
topwords['LSA']=top_words(components_lsa, n_top_words)

# %%
# LDA
from sklearn.decomposition import LatentDirichletAllocation as LDA

lda = LDA(n_topics=ntopics, 
          doc_topic_prior=None, # Prior = 1/n_documents
          topic_word_prior=1/ntopics,
          learning_decay=0.7, # Convergence rate.
          learning_offset=10.0, # Causes earlier iterations to have less influence on the learning
          max_iter=10, # when to stop even if the model is not converging (to prevent running forever)
          evaluate_every=-1, # Do not evaluate perplexity, as it slows training time.
          mean_change_tol=0.001, # Stop updating the document topic distribution in the E-step when mean change is < tol
          max_doc_update_iter=100, # When to stop updating the document topic distribution in the E-step even if tol is not reached
          n_jobs=-1, # Use all available CPUs to speed up processing time.
          verbose=0, # amount of output to give while iterating
          random_state=0
         )

emma_paras_lda = lda.fit_transform(emma_paras_tfidf) 

components_lda = word_topic(emma_paras_tfidf, emma_paras_lda, terms)

topwords['LDA']=top_words(components_lda, n_top_words)
# Out:
# C:\Users\Loren\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# C:\Users\Loren\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %%
# NNMF

from sklearn.decomposition import NMF

nmf = NMF(alpha=0.0, 
          init='nndsvdar', # how starting value are calculated
          l1_ratio=0.0, # Sets whether regularization is L2 (0), L1 (1), or a combination (values between 0 and 1)
          max_iter=200, # when to stop even if the model is not converging (to prevent running forever)
          n_components=ntopics, 
          random_state=0, 
          solver='cd', # Use Coordinate Descent to solve
          tol=0.0001, # model will stop if tfidf-WH <= tol
          verbose=0 # amount of output to give while iterating
         )
emma_paras_nmf = nmf.fit_transform(emma_paras_tfidf) 

components_nmf = word_topic(emma_paras_tfidf, emma_paras_nmf, terms)

topwords['NNMF']=top_words(components_nmf, n_top_words)

# %% [markdown]
# We are mostly using the default settings for each method, but explicitly printing them so it is clear what is going on and how each model can be modified.  sklearn has such nice parallel structure for its various topic extraction methods that we could probably have abstracted the code even further.

# %% [markdown]
# # Inspecting the topics
#
# For each topic, we list the ten most-relevant words according to each method:

# %%
for topic in range(ntopics):
    print('Topic {}:'.format(topic))
    print(topwords.loc[topic])
# Out:
# Topic 0:
#                LSA              LDA             NNMF
# 0          oh 97.6         mr 51.75         oh 30.12
# 0         yes 4.76       emma 49.65         yes 0.52
# 0       thank 1.63       said 40.12       sorry 0.16
# 0  difference 1.56        mrs 35.04  difference 0.15
# 0        just 1.43       miss 30.12        just 0.12
# 0     harriet 1.29    harriet 27.06        papa 0.12
# 0       sorry 1.28     weston 25.63        week 0.11
# 0       short 1.17  knightley 24.39       short 0.11
# 0        papa 1.15      elton 23.29    recollect 0.1
# 0   recollect 1.01        did 20.65      letter 0.09
# Topic 1:
#                LSA           LDA            NNMF
# 1       emma 58.56      oh 56.59         mr 7.29
# 1         mr 58.02      ah 18.06        mrs 4.26
# 1       said 50.15     emma 7.16      elton 3.41
# 1        mrs 47.15     said 4.97  knightley 3.24
# 1       miss 37.91       mr 4.88     weston 3.15
# 1    harriet 33.83  chapter 4.14       miss 2.99
# 1     weston 32.27  harriet 3.68  woodhouse 2.09
# 1      elton 28.06      mrs 3.18       said 1.88
# 1        did 27.46      yes 2.99    fairfax 1.84
# 1  knightley 26.25      miss 2.8       emma 1.47
# Topic 2:
#              LSA            LDA           NNMF
# 2       ah 31.15  chapter 20.22       ah 12.89
# 2      sure 3.77       oh 10.34      sure 0.35
# 2        say 1.1       yes 8.96   believe 0.18
# 2   believe 0.82      dear 7.53       say 0.18
# 2     sorry 0.81       emma 7.1     shake 0.09
# 2      shake 0.5      sure 6.75     hands 0.09
# 2      hands 0.5        mr 6.11     sorry 0.09
# 2      poor 0.45     thank 5.59  grievous 0.08
# 2  grievous 0.44      true 5.45      come 0.07
# 2     spring 0.4      said 5.19    taylor 0.07
# Topic 3:
#              LSA           LDA           NNMF
# 3  chapter 33.91       oh 9.79  chapter 10.46
# 3        iii 3.2     emma 5.72       iii 0.68
# 3         ii 3.2     good 4.36        ii 0.68
# 3      xiii 2.52       mr 4.12       vii 0.66
# 3       xiv 2.52     said 3.93        xv 0.66
# 3       xvi 2.52     read 3.26       xvi 0.66
# 3        xi 2.52      mrs 3.26      xvii 0.66
# 3     xviii 2.52       ah 3.06     xviii 0.66
# 3        iv 2.52  chapter 2.99       xii 0.66
# 3       xii 2.52     dear 2.79        xi 0.66
# Topic 4:
#                LSA           LDA          NNMF
# 4         mr 38.36       oh 9.73     emma 9.27
# 4  knightley 19.02      emma 7.5     said 5.84
# 4      elton 14.64       mr 5.62     dear 3.52
# 4      weston 9.34      said 5.1  harriet 2.89
# 4         mrs 6.29    shall 5.04      yes 2.29
# 4        john 4.51  harriet 4.64    think 1.74
# 4   churchill 3.53      mrs 4.36       mr 1.69
# 4   woodhouse 3.46     dear 3.23      say 1.52
# 4      martin 3.13       ah 3.06    thing 1.32
# 4        frank 2.6  chapter 2.99     sure 1.27

# %% [markdown]
# A number of things are clear.  First, some topics are shared, though the order of topics varies- the 'oh' topic is first for LSA and NNMF, but second for LDA.  And second, the content of some of the topics varies considerably across methods.  This is a clear argument for using multiple methods when exploring topics.
#
# # Sparsity
#
# Now let's examine sparsity by looking at the distributions of loadings for the words 'marriage', 'love', 'emma', and 'oh' across the methods:

# %%
# The words to look at.
targetwords=['marriage','love','emma','oh']

# Storing the loadings.
wordloadings=pd.DataFrame(columns=targetwords)

# For each word, extracting and string the loadings for each method.
for word in targetwords:
    loadings=components_lsa.loc[word].append(
        components_lda.loc[word]).append(
            components_nmf.loc[word])
    print(loadings)
    wordloadings[word]=loadings

# Labeling the data by method and providing an ordering variable for graphing purposes. 
wordloadings['method']=np.repeat(['LSA','LDA','NNMF'], 5, axis=0)
wordloadings['loading']=[0,1,2,3,4]*3

sns.set(style="darkgrid")

for word in targetwords:
    sns.barplot(x="method", y=word, hue="loading", data=wordloadings)
    plt.title(word)
    plt.ylabel("")
    plt.show()
# Out:
# 0    4.691144e-02
# 1    3.096637e+00
# 2   -8.628550e-02
# 3    8.668115e-03
# 4    7.423949e-01
# 0    1.992386e+00
# 1    1.957083e-01
# 2    2.533039e-01
# 3    5.528729e-01
# 4    5.296164e-01
# 0    1.763702e-04
# 1    1.057906e-01
# 2    9.844702e-05
# 3    4.073648e-15
# 4    3.514428e-02
# Name: marriage, dtype: float64
# 0    7.100199e-02
# 1    8.783243e+00
# 2   -1.789705e-01
# 3   -3.766844e-02
# 4   -2.832976e+00
# 0    6.616265e+00
# 1    6.468237e-01
# 2    1.133355e+00
# 3    9.640096e-01
# 4    1.002675e+00
# 0    5.304526e-04
# 1    2.516977e-01
# 2    2.047230e-03
# 3    1.206335e-13
# 4    4.286042e-01
# Name: love, dtype: float64
# 0    5.856342e-01
# 1    5.855569e+01
# 2   -1.370918e+00
# 3    1.566077e-01
# 4   -4.071772e+01
# 0    4.964651e+01
# 1    7.164297e+00
# 2    7.104396e+00
# 3    5.719460e+00
# 4    7.496515e+00
# 0    1.816604e-02
# 1    1.466726e+00
# 2    1.317691e-02
# 3    5.640619e-13
# 4    9.273954e+00
# Name: emma, dtype: float64
# 0    9.759904e+01
# 1    5.232720e-01
# 2   -8.956893e-03
# 3    3.838096e-03
# 4   -3.462989e-01
# 0    1.154813e+01
# 1    5.658545e+01
# 2    1.033519e+01
# 3    9.788951e+00
# 4    9.731062e+00
# 0    3.012174e+01
# 1    6.451992e-02
# 2    2.318873e-03
# 3    2.935160e-12
# 4    2.646853e-01
# Name: oh, dtype: float64

# %%
wordloadings
# Out:
#        marriage          love          emma            oh method  loading
# 0  4.691144e-02  7.100199e-02  5.856342e-01  9.759904e+01    LSA        0
# 1  3.096637e+00  8.783243e+00  5.855569e+01  5.232720e-01    LSA        1
# 2 -8.628550e-02 -1.789705e-01 -1.370918e+00 -8.956893e-03    LSA        2
# 3  8.668115e-03 -3.766844e-02  1.566077e-01  3.838096e-03    LSA        3
# 4  7.423949e-01 -2.832976e+00 -4.071772e+01 -3.462989e-01    LSA        4
# 0  1.992386e+00  6.616265e+00  4.964651e+01  1.154813e+01    LDA        0
# 1  1.957083e-01  6.468237e-01  7.164297e+00  5.658545e+01    LDA        1
# 2  2.533039e-01  1.133355e+00  7.104396e+00  1.033519e+01    LDA        2
# 3  5.528729e-01  9.640096e-01  5.719460e+00  9.788951e+00    LDA        3
# 4  5.296164e-01  1.002675e+00  7.496515e+00  9.731062e+00    LDA        4
# 0  1.763702e-04  5.304526e-04  1.816604e-02  3.012174e+01   NNMF        0
# 1  1.057906e-01  2.516977e-01  1.466726e+00  6.451992e-02   NNMF        1
# 2  9.844702e-05  2.047230e-03  1.317691e-02  2.318873e-03   NNMF        2
# 3  4.073648e-15  1.206335e-13  5.640619e-13  2.935160e-12   NNMF        3
# 4  3.514428e-02  4.286042e-01  9.273954e+00  2.646853e-01   NNMF        4

# %%
components_lsa.loc['emma']
# Out:
# 0     0.585634
# 1    58.555685
# 2    -1.370918
# 3     0.156608
# 4   -40.717718
# Name: emma, dtype: float64

# %% [markdown]
# LSA is the method most likely to have high loadings on more than one topic for the same word.  LDA tends to have one high loading and some lower loadings.  Loadings for NNMF are lower all around, and the most sparse, with some of the topics having loadings of zero on each word.
#
# # Challenge: Topic extraction on new data
#
# Take the well-known [20 newsgroups](http://qwone.com/~jason/20Newsgroups/) dataset and use each of the methods on it.  Your goal is to determine which method, if any, best reproduces the topics represented by the newsgroups.  Write up a report where you evaluate each method in light of the 'ground truth'- the known source of each newsgroup post.  Which works best, and why do you think this is the case?

# %%
from sklearn.datasets import fetch_20newsgroups
news = fetch_20newsgroups(remove=('headers', 'footers', 'quotes'), subset='all')

# %%
news.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
news.data[0]
# Out:
# "\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n"

# %%
# Creating the tf-idf matrix.
vectorizer = TfidfVectorizer(stop_words='english')
news_tfidf=vectorizer.fit_transform(news.data)

# %%
# Getting the word list.
terms = vectorizer.get_feature_names()

# Number of topics.
ntopics=20

# %%
# LSA

from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer

svd= TruncatedSVD(ntopics)
lsa = make_pipeline(svd, Normalizer(copy=False))
news_lsa = lsa.fit_transform(news_tfidf)

components_lsa = word_topic(news_tfidf, news_lsa, terms)

# Number of words to look at for each topic.
n_top_words = 10

topwords=pd.DataFrame()
topwords['LSA']=top_words(components_lsa, n_top_words)

# %%
print(news_lsa.shape)
print(news.target.shape)
# Out:
# (18846, 20)
# (18846,)

# %%
# LDA
from sklearn.decomposition import LatentDirichletAllocation as LDA

lda = LDA(n_topics=ntopics, 
          doc_topic_prior=None, # Prior = 1/n_documents
          topic_word_prior=1/ntopics,
          learning_decay=0.7, # Convergence rate.
          learning_offset=10.0, # Causes earlier iterations to have less influence on the learning
          max_iter=10, # when to stop even if the model is not converging (to prevent running forever)
          evaluate_every=-1, # Do not evaluate perplexity, as it slows training time.
          mean_change_tol=0.001, # Stop updating the document topic distribution in the E-step when mean change is < tol
          max_doc_update_iter=100, # When to stop updating the document topic distribution in the E-step even if tol is not reached
          n_jobs=-1, # Use all available CPUs to speed up processing time.
          verbose=0, # amount of output to give while iterating
          
         )

news_lda = lda.fit_transform(news_tfidf) 

components_lda = word_topic(news_tfidf, news_lda, terms)

topwords['LDA']=top_words(components_lda, n_top_words)
# Out:
# C:\Users\Loren\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# C:\Users\Loren\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %%
# NNMF

from sklearn.decomposition import NMF

nmf = NMF(alpha=0.0, 
          init='nndsvdar', # how starting value are calculated
          l1_ratio=0.0, # Sets whether regularization is L2 (0), L1 (1), or a combination (values between 0 and 1)
          max_iter=200, # when to stop even if the model is not converging (to prevent running forever)
          n_components=ntopics, 
          random_state=0, 
          solver='cd', # Use Coordinate Descent to solve
          tol=0.0001, # model will stop if tfidf-WH <= tol
          verbose=0 # amount of output to give while iterating
         )
news_nmf = nmf.fit_transform(news_tfidf) 

components_nmf = word_topic(news_tfidf, news_nmf, terms)

topwords['NNMF']=top_words(components_nmf, n_top_words)

# %%
for topic in range(ntopics):
    print('Topic {}:'.format(topic))
    print(topwords.loc[topic])
# Out:
# Topic 0:
#              LSA          LDA         NNMF
# 0     like 146.5    know 1.98     don 4.55
# 0      don 145.9    just 1.87    just 4.37
# 0    just 144.54    like 1.85    like 3.56
# 0    know 132.62     don 1.77   think 3.52
# 0  people 128.54     does 1.7    know 2.59
# 0   think 122.88  thanks 1.69  people 2.46
# 0    does 102.35   think 1.52      ve 2.22
# 0    time 101.13  people 1.45    good 2.11
# 0     good 98.73     use 1.32    time 2.03
# 0      use 98.67    good 1.29     say 1.87
# Topic 1:
#               LSA          LDA              NNMF
# 1   windows 53.64    know 1.94       window 3.71
# 1    thanks 49.18    just 1.86      problem 1.75
# 1     drive 32.34    like 1.82          use 1.64
# 1       card 32.3     don 1.76       server 1.44
# 1       dos 30.19    does 1.69  application 1.28
# 1  software 27.58  thanks 1.62        using 1.28
# 1        pc 27.56   think 1.51      program 1.21
# 1      file 27.26  people 1.42      windows 1.19
# 1       use 26.29     use 1.36        motif 1.11
# 1   program 25.22    good 1.24      display 1.05
# Topic 2:
#                 LSA           LDA             NNMF
# 2         god 73.62     know 1.91        god 11.35
# 2       jesus 28.53     just 1.87       jesus 4.19
# 2     windows 26.51     like 1.85       bible 2.51
# 2       bible 18.22      don 1.76      believe 2.5
# 2        does 17.52     does 1.69      christ 2.21
# 2      thanks 16.01   thanks 1.63      people 2.08
# 2    christian 16.0  feustel 1.61   christian 2.02
# 2      christ 15.71    think 1.51       faith 2.01
# 2  christians 14.93   people 1.42  christians 1.89
# 2       faith 14.35       use 1.3         say 1.78
# Topic 3:
#             LSA          LDA             NNMF
# 3   drive 43.53    know 1.94       drive 6.25
# 3    game 25.68     just 1.9        disk 2.07
# 3     god 24.79    like 1.84        hard 1.96
# 3    scsi 21.77     don 1.77      drives 1.62
# 3   games 18.85     does 1.7        scsi 1.49
# 3    team 16.01  thanks 1.63         ide 1.31
# 3    year 15.81   think 1.52      floppy 1.27
# 3    hard 14.91  people 1.46  controller 1.06
# 3    card 14.56      use 1.3     problem 0.82
# 3  drives 13.57    good 1.25         mac 0.77
# Topic 4:
#                 LSA          LDA             NNMF
# 4       drive 36.36       ax 6.2         key 5.48
# 4  government 21.51    know 2.67        chip 3.96
# 4        scsi 21.23    just 2.48  encryption 3.08
# 4        chip 19.71     don 2.47     clipper 3.04
# 4         key 18.79    like 2.46        keys 2.54
# 4     clipper 13.69    does 2.18  government 2.15
# 4  encryption 13.14  thanks 2.12      escrow 1.91
# 4      people 12.74   think 1.99         use 1.91
# 4         law 12.65     use 1.78   algorithm 1.68
# 4         use 12.38    good 1.73       phone 1.52
# Topic 5:
#              LSA          LDA          NNMF
# 5  windows 40.08    know 2.25   thanks 8.26
# 5      dos 23.43    like 2.17   advance 3.2
# 5    think 17.82    baden 2.1     mail 2.64
# 5   people 14.97    just 2.07       hi 2.49
# 5  problem 13.34     don 2.06      know 2.3
# 5     file 12.53  thanks 1.89  looking 2.01
# 5      don 11.54  people 1.85     help 1.92
# 5    drive 10.96    does 1.85     does 1.91
# 5     just 10.71      ve 1.68     info 1.74
# 5       os 10.47   think 1.62     like 1.61
# Topic 6:
#                 LSA          LDA          NNMF
# 6         god 23.24    know 1.93     team 3.48
# 6         key 21.73    just 1.87     year 2.73
# 6         game 20.3    like 1.82  players 1.63
# 6          00 17.19     don 1.77     good 1.52
# 6       games 15.22    does 1.69   season 1.45
# 6          10 14.72  thanks 1.63     game 1.43
# 6        chip 14.14   think 1.52    games 1.36
# 6        team 13.58  people 1.42     play 1.18
# 6          15 10.75     use 1.29    think 1.17
# 6  encryption 10.59    good 1.26      win 1.17
# Topic 7:
#               LSA          LDA           NNMF
# 7       edu 19.28    know 1.93        00 4.42
# 7        00 17.94    just 1.87         10 1.4
# 7    people 16.56    like 1.84        50 1.15
# 7       new 15.89     don 1.76        20 0.97
# 7    israel 13.37    does 1.66        15 0.93
# 7        10 11.87  thanks 1.63      sale 0.93
# 7       000 11.81   think 1.51        25 0.86
# 7      sale 11.73  people 1.46       new 0.81
# 7  armenian 11.52     use 1.29  shipping 0.75
# 7      jews 11.38    good 1.26     price 0.66
# Topic 8:
#                LSA          LDA            NNMF
# 8        edu 26.25    know 1.93        geb 3.18
# 8       pitt 12.64    just 1.88        dsl 3.14
# 8      banks 12.11    like 1.84      n3jxp 3.14
# 8     gordon 12.06     don 1.76      cadre 3.14
# 8  surrender 11.74    does 1.68   chastity 3.13
# 8        geb 11.68  thanks 1.63       pitt 3.13
# 8       soon 11.64   think 1.54  skepticism 3.1
# 8       cadre 11.3  people 1.45   intellect 3.1
# 8  intellect 11.29     use 1.32   shameful 3.09
# 8   shameful 11.28    good 1.25  surrender 3.07
# Topic 9:
#             LSA            LDA           NNMF
# 9     car 37.55    like 201.76      game 5.47
# 9    just 24.77    just 200.84     games 2.42
# 9    bike 21.46     don 200.46      espn 1.47
# 9    good 21.28    know 195.92  baseball 1.35
# 9    like 18.12  people 179.64    hockey 1.31
# 9      ve 17.26   think 169.71      team 0.74
# 9     new 15.17     does 162.6       don 0.74
# 9  engine 13.34     use 144.77      play 0.71
# 9      use 12.9    time 140.78      night 0.7
# 9    cars 12.61    good 139.05      pens 0.65
# Topic 10:
#               LSA          LDA          NNMF
# 10     card 42.87    know 1.97     card 7.72
# 10     video 22.6    just 1.93  monitor 3.92
# 10  monitor 21.21    like 1.83    video 3.85
# 10  drivers 12.16      don 1.8      vga 2.12
# 10      bus 12.04    does 1.71      bus 2.06
# 10    cards 12.01  thanks 1.64    cards 1.95
# 10     does 12.01   think 1.55  windows 1.87
# 10      vga 10.23  people 1.43  drivers 1.78
# 10   driver 10.14     use 1.32    color 1.75
# 10     board 9.49    good 1.28    apple 1.74
# Topic 11:
#                LSA              LDA          NNMF
# 11   windows 28.23         edu 6.84  windows 9.06
# 11       car 21.49         geb 5.35       dos 4.8
# 11     thanks 20.4       cadre 5.31       os 2.04
# 11       dos 15.32         dsl 5.28       ms 1.87
# 11       new 12.58       n3jxp 5.28     file 1.59
# 11        00 11.45    chastity 5.27      run 1.44
# 11      know 10.73        pitt 5.25  running 1.37
# 11        key 8.92  skepticism 5.21      use 1.36
# 11  government 8.9     shameful 5.2  version 1.34
# 11       bike 8.64    intellect 5.2   thanks 1.28
# Topic 12:
#              LSA          LDA         NNMF
# 12     don 29.05    know 1.91     car 5.98
# 12  people 26.14    just 1.85    bike 2.04
# 12   think 23.25    like 1.82     new 1.89
# 12      00 16.05     don 1.75    good 1.52
# 12     mail 13.0    does 1.65    cars 1.44
# 12    post 10.61  thanks 1.61  engine 1.35
# 12      edu 9.94   think 1.51    like 1.33
# 12     sale 9.93  people 1.42    just 1.18
# 12     just 9.31     use 1.29   miles 1.17
# 12     list 9.17    good 1.23     used 1.1
# Topic 13:
#              LSA          LDA          NNMF
# 13    does 47.53    know 1.92     does 8.41
# 13    know 33.11    just 1.86     know 7.89
# 13      00 16.75    like 1.82   thanks 2.44
# 13     don 14.38     don 1.76      don 2.29
# 13  israel 10.87    does 1.65     like 2.07
# 13       10 7.72  thanks 1.63  anybody 1.84
# 13    space 7.69   think 1.51     just 1.75
# 13     mean 7.67  people 1.42   people 1.68
# 13      use 6.49     use 1.29      use 1.41
# 13     jews 6.37    good 1.23  windows 1.36
# Topic 14:
#               LSA          LDA               NNMF
# 14     just 21.63    know 2.04        israel 6.55
# 14   window 18.09    just 1.92          jews 3.38
# 14   israel 16.68    like 1.91       israeli 3.04
# 14  problem 12.85     don 1.79          arab 2.64
# 14      don 11.96    does 1.72        jewish 2.21
# 14       00 11.15  thanks 1.69         arabs 1.89
# 14   thanks 10.12   think 1.54        people 1.32
# 14     jews 10.05  people 1.44         peace 1.28
# 14      want 9.98     use 1.35         state 1.25
# 14   israeli 7.95     good 1.3  palestinians 1.17
# Topic 15:
#               LSA          LDA             NNMF
# 15      did 19.62    know 1.94      people 8.09
# 15      fbi 17.12     just 1.9  government 3.79
# 15   window 15.85    like 1.85       right 2.98
# 15     does 15.35     don 1.78         gun 2.93
# 15  problem 14.59    does 1.71         don 2.87
# 15   koresh 14.19  thanks 1.63       think 2.67
# 15     batf 11.84   think 1.53         law 2.44
# 15      gun 11.64  people 1.47         fbi 2.38
# 15    space 10.31     use 1.29         did 2.35
# 15        00 9.92    good 1.25        just 2.34
# Topic 16:
#             LSA          LDA            NNMF
# 16    file 23.9    know 1.95   armenian 5.03
# 16   know 18.81     just 1.9  armenians 4.05
# 16  files 16.05    like 1.84     turkish 3.0
# 16    fbi 11.37     don 1.79   genocide 2.03
# 16    car 11.27    does 1.78     turkey 1.87
# 16   does 10.84  thanks 1.63     people 1.82
# 16     gun 9.42   think 1.51    armenia 1.81
# 16    batf 8.83  people 1.43     muslim 1.68
# 16  format 8.59     use 1.35      turks 1.59
# 16  koresh 8.57    good 1.24     soviet 1.44
# Topic 17:
#                 LSA          LDA           NNMF
# 17       know 28.01    know 1.93      file 5.95
# 17        don 20.31     like 1.9     files 3.91
# 17       said 13.25    just 1.89   program 2.91
# 17   armenian 11.15     don 1.79    windows 2.2
# 17  armenians 10.19    does 1.74    format 2.14
# 17     program 8.96  thanks 1.65       ftp 2.09
# 17        didn 8.71   think 1.52     image 1.94
# 17     turkish 7.39  people 1.43       gif 1.84
# 17       space 7.14     use 1.33       use 1.54
# 17         let 7.04    good 1.24  graphics 1.35
# Topic 18:
#              LSA          LDA              NNMF
# 18    just 28.32    know 1.93          edu 3.96
# 18     did 16.47    just 1.89        space 3.36
# 18  israel 14.55    like 1.85         mail 3.31
# 18      ve 13.76     don 1.79         list 2.82
# 18     know 13.6    does 1.69          com 2.37
# 18    file 12.71  thanks 1.64         send 2.11
# 18     scsi 11.8   think 1.52  information 2.05
# 18    bike 10.57  people 1.42         like 2.03
# 18      got 9.83     use 1.38     software 1.94
# 18      com 9.75    good 1.24      address 1.93
# Topic 19:
#               LSA          LDA            NNMF
# 19      edu 23.34    know 1.93        scsi 7.4
# 19      com 21.07    just 1.86        ide 2.61
# 19     does 16.57    like 1.86       drive 2.3
# 19      mac 14.44     don 1.79  controller 2.0
# 19      mail 13.8    does 1.65        bus 1.96
# 19    apple 12.79  thanks 1.65     drives 1.08
# 19      don 11.41   think 1.51        isa 1.03
# 19    modem 10.49  people 1.42          pc 1.0
# 19     list 10.33     use 1.31         bit 1.0
# 19  problem 10.04    good 1.23       data 0.94

# %% [markdown]
# Comparing the topics based on the top words to the actual 'ground truth' topics reveals a few things. First, LDA produced almost the same list of top words for every topic except 1. LSA was able to identify some of the topics, but NNMF performed the best. Comparing the list of actual topics to the top words, you can see most of the topics have been identified by the model.
