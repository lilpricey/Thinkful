# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import networkx as nx
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
# %matplotlib inline

#!python -m spacy download en

# %% [markdown]
# # Summarizing Text
#
# Let's try out extractive summarization using the first four paragraphs of [The Great Gatsby](http://gutenberg.net.au/ebooks02/0200041h.html).
#
# First, we'll try to extract the most representative sentence.  Then, we'll extract keywords.
#
# ## Sentence extraction
#
# The steps of our sentence extraction process:
#
# 1. Parse and tokenize the text using spaCy, and divide into sentences.
# 2. Calculate the tf-idf matrix.
# 3. Calculate similarity scores.
# 4. Calculate TextRank: We're going to use the ´networkx´ package to run the TextRank algorithm.
#
# Let's get started!

# %%
# Importing the text the lazy way.
gatsby="In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. \"Whenever you feel like criticizing any one,\" he told me, \"just remember that all the people in this world haven't had the advantages that you've had.\" He didn't say any more but we've always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence I'm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret griefs of wild, unknown men. Most of the confidences were unsought--frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they express them are usually plagiaristic and marred by obvious suppressions. Reserving judgments is a matter of infinite hope. I am still a little afraid of missing something if I forget that, as my father snobbishly suggested, and I snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth. And, after boasting this way of my tolerance, I come to the admission that it has a limit. Conduct may be founded on the hard rock or the wet marshes but after a certain point I don't care what it's founded on. When I came back from the East last autumn I felt that I wanted the world to be in uniform and at a sort of moral attention forever; I wanted no more riotous excursions with privileged glimpses into the human heart. Only Gatsby, the man who gives his name to this book, was exempt from my reaction--Gatsby who represented everything for which I have an unaffected scorn. If personality is an unbroken series of successful gestures, then there was something gorgeous about him, some heightened sensitivity to the promises of life, as if he were related to one of those intricate machines that register earthquakes ten thousand miles away. This responsiveness had nothing to do with that flabby impressionability which is dignified under the name of the \"creative temperament\"--it was an extraordinary gift for hope, a romantic readiness such as I have never found in any other person and which it is not likely I shall ever find again. No--Gatsby turned out all right at the end; it is what preyed on Gatsby, what foul dust floated in the wake of his dreams that temporarily closed out my interest in the abortive sorrows and short-winded elations of men."

# We want to use the standard english-language parser.
parser = spacy.load('en')

# Parsing Gatsby.
gatsby = parser(gatsby)

# Dividing the text into sentences and storing them as a list of strings.
sentences=[]
for span in gatsby.sents:
    # go from the start to the end of each span, returning each token in the sentence
    # combine each token using join()
    sent = ''.join(gatsby[i].string for i in range(span.start, span.end)).strip()
    sentences.append(sent)

# Creating the tf-idf matrix.
counter = TfidfVectorizer(lowercase=False, 
                          stop_words=None,
                          ngram_range=(1, 1), 
                          analyzer=u'word', 
                          max_df=.5, 
                          min_df=1,
                          max_features=None, 
                          vocabulary=None, 
                          binary=False)

#Applying the vectorizer
data_counts=counter.fit_transform(sentences)

# %% [markdown]
# # Similarity
#
# So far, this is all (hopefully) familiar: We've done text parsing and the tf-idf calculation before.  We should now have sentences represented as vectors, with each word having a score based on how often it occurs in the sentence divided by how often it occurs in the whole text.
#
# Now let's calculate the similarity scores for the sentences and apply the TextRank algorithm.  Because TextRank is based on Google's PageRank algorithm, the function is called 'pagerank'.  The hyperparameters are the damping parameter ´alpha´ and the convergence parameter ´tol´.

# %%
# Calculating similarity
similarity = data_counts * data_counts.T

# Identifying the sentence with the highest rank.
nx_graph = nx.from_scipy_sparse_matrix(similarity)
ranks=nx.pagerank(nx_graph, alpha=.85, tol=.00000001)

ranked = sorted(((ranks[i],s) for i,s in enumerate(sentences)),
                reverse=True)
print(ranked[0])
# Out:
# (0.07478177112861596, 'This responsiveness had nothing to do with that flabby impressionability which is dignified under the name of the "creative temperament"--it was an extraordinary gift for hope, a romantic readiness such as I have never found in any other person and which it is not likely I shall ever find again.')

# %% [markdown]
# Since a lot of Gatsby is about the narrator acting as the observer of other peoples' sordid secrets, this seems pretty good.  Now, let's extract some keywords.
#
# # Keyword summarization
#
# 1) Parse and tokenize text (already done).
# 2) Filter out stopwords, choose only nouns and adjectives.
# 3) Calculate the neighbors of words (we'll use a window of 4).
# 4) Run TextRank on the neighbor matrix.

# %%
# Removing stop words and punctuation, then getting a list of all unique words in the text
gatsby_filt = [word for word in gatsby if word.is_stop==False and (word.pos_=='NOUN' or word.pos_=='ADJ')]
words=set(gatsby_filt)

#Creating a grid indicating whether words are within 4 places of the target word
adjacency=pd.DataFrame(columns=words,index=words,data=0)

#Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby):
    # Checking if any of the word's next four neighbors are in the word list 
    if any([word == item for item in gatsby_filt]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby)-(len(gatsby)-(i+5)))
        # The potential neighbors.
        nextwords=gatsby[i+1:end]
        # Filtering the neighbors to select only those in the word list
        inset=[x in gatsby_filt for x in nextwords]
        neighbors=[nextwords[i] for i in range(len(nextwords)) if inset[i]]
        print(nextwords, inset, neighbors)
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            #Access a group of rows and columns by label(s) or a boolean array. 
            adjacency.loc[word,neighbors]=adjacency.loc[word,neighbors]+1

print('done!')
        
print(adjacency)
# Out:
# and more vulnerable years [False, False, True, True] [vulnerable, years]
# years my father gave [True, False, True, False] [years, father]
# my father gave me [False, True, False, False] [father]
# gave me some advice [False, False, False, True] [advice]
# that I've been [False, False, False, False] []
# ever since. " [False, False, False, False] []
# in this world have [False, False, True, False] [world]
# haven't had the [False, False, False, False] []
# that you've had [False, False, False, False] []
# in a reserved way [False, False, True, True] [reserved, way]
# way, and I [True, False, False, False] [way]
# , and I understood [False, False, False, False] []
# deal more than that [True, False, False, False] [deal]
# more than that. [False, False, False, False] []
# I'm inclined to [False, False, True, False] [inclined]
# to reserve all judgments [False, False, False, True] [judgments]
# , a habit that [False, False, True, False] [habit]
# that has opened up [False, False, False, False] []
# natures to me and [True, False, False, False] [natures]
# to me and also [False, False, False, False] []
# of not a few [False, False, False, False] []
# bores. The abnormal [True, False, False, True] [bores, abnormal]
# . The abnormal mind [False, False, True, True] [abnormal, mind]
# mind is quick to [True, False, True, False] [mind, quick]
# is quick to detect [False, True, False, False] [quick]
# to detect and attach [False, False, False, False] []
# when it appears in [False, False, False, False] []
# person, and so [True, False, False, False] [person]
# , and so it [False, False, False, False] []
# I was unjustly accused [False, False, False, False] []
# , because I was [False, False, False, False] []
# to the secret griefs [False, False, True, True] [secret, griefs]
# griefs of wild, [True, False, True, False] [griefs, wild]
# of wild, unknown [False, True, False, True] [wild, unknown]
# , unknown men. [False, True, True, False] [unknown, men]
# men. Most of [True, False, True, False] [men, Most]
# . Most of the [False, True, False, False] [Most]
# of the confidences were [False, False, True, False] [confidences]
# were unsought--frequently [False, False, False, False] []
# , preoccupation, or [False, True, False, False] [preoccupation]
# , or a hostile [False, False, False, True] [hostile]
# levity when I realized [True, False, False, False] [levity]
# when I realized by [False, False, False, False] []
# sign that an intimate [True, False, False, True] [sign, intimate]
# that an intimate revelation [False, False, True, True] [intimate, revelation]
# revelation was quivering on [True, False, False, False] [revelation]
# was quivering on the [False, False, False, False] []
# --for the intimate [False, False, False, True] [intimate]
# revelations of young men [True, False, True, True] [revelations, young, men]
# of young men or [False, True, True, False] [young, men]
# men or at least [True, False, False, False] [men]
# or at least the [False, False, False, False] []
# in which they express [False, False, False, False] []
# and marred by obvious [False, False, False, True] [obvious]
# suppressions. Reserving judgments [True, False, True, True] [suppressions, Reserving, judgments]
# . Reserving judgments is [False, True, True, False] [Reserving, judgments]
# judgments is a matter [True, False, False, True] [judgments, matter]
# is a matter of [False, False, True, False] [matter]
# of infinite hope. [False, True, True, False] [infinite, hope]
# hope. I am [True, False, False, False] [hope]
# . I am still [False, False, False, False] []
# afraid of missing something [True, False, False, False] [afraid]
# of missing something if [False, False, False, False] []
# snobbishly suggested, and [False, False, False, False] []
# of the fundamental decencies [False, False, True, True] [fundamental, decencies]
# decencies is parcelled out [True, False, False, False] [decencies]
# is parcelled out unequally [False, False, False, False] []
# . And, after [False, False, False, False] []
# of my tolerance, [False, False, True, False] [tolerance]
# , I come to [False, False, False, False] []
# that it has a [False, False, False, False] []
# . Conduct may be [False, True, False, False] [Conduct]
# may be founded on [False, False, False, False] []
# rock or the wet [True, False, False, True] [rock, wet]
# or the wet marshes [False, False, True, True] [wet, marshes]
# marshes but after a [True, False, False, False] [marshes]
# but after a certain [False, False, False, True] [certain]
# point I don't [True, False, False, False] [point]
# I don't care [False, False, False, False] []
# I felt that I [False, False, False, False] []
# to be in uniform [False, False, False, True] [uniform]
# and at a sort [False, False, False, True] [sort]
# of moral attention forever [False, True, True, False] [moral, attention]
# attention forever; I [True, False, False, False] [attention]
# forever; I wanted [False, False, False, False] []
# excursions with privileged glimpses [True, False, True, True] [excursions, privileged, glimpses]
# with privileged glimpses into [False, True, True, False] [privileged, glimpses]
# glimpses into the human [True, False, False, True] [glimpses, human]
# into the human heart [False, False, True, True] [human, heart]
# heart. Only Gatsby [True, False, False, False] [heart]
# . Only Gatsby, [False, False, False, False] []
# who gives his name [False, False, False, False] []
# , was exempt from [False, False, True, False] [exempt]
# from my reaction-- [False, False, True, False] [reaction]
# --Gatsby who represented [False, False, False, False] []
# scorn. If personality [True, False, False, True] [scorn, personality]
# . If personality is [False, False, True, False] [personality]
# is an unbroken series [False, False, True, True] [unbroken, series]
# series of successful gestures [True, False, True, True] [series, successful, gestures]
# of successful gestures, [False, True, True, False] [successful, gestures]
# gestures, then there [True, False, False, False] [gestures]
# , then there was [False, False, False, False] []
# about him, some [False, False, False, False] []
# to the promises of [False, False, True, False] [promises]
# of life, as [False, True, False, False] [life]
# , as if he [False, False, False, False] []
# machines that register earthquakes [True, False, False, True] [machines, earthquakes]
# that register earthquakes ten [False, False, True, False] [earthquakes]
# ten thousand miles away [False, False, True, False] [miles]
# away. This responsiveness [False, False, False, True] [responsiveness]
# had nothing to do [False, False, False, False] []
# impressionability which is dignified [True, False, False, True] [impressionability, dignified]
# which is dignified under [False, False, True, False] [dignified]
# under the name of [False, False, False, False] []
# temperament"--it was [True, False, False, False] [temperament]
# "--it was an [False, False, False, False] []
# gift for hope, [True, False, True, False] [gift, hope]
# for hope, a [False, True, False, False] [hope]
# , a romantic readiness [False, False, True, True] [romantic, readiness]
# readiness such as I [True, False, False, False] [readiness]
# such as I have [False, False, False, False] []
# and which it is [False, False, False, False] []
# I shall ever find [False, False, False, False] []
# ; it is what [False, False, False, False] []
# dust floated in the [True, False, False, False] [dust]
# floated in the wake [False, False, False, True] [wake]
# of his dreams that [False, False, True, False] [dreams]
# that temporarily closed out [False, False, False, False] []
# in the abortive sorrows [False, False, True, True] [abortive, sorrows]
# sorrows and short- [True, False, False, False] [sorrows]
# and short-winded [False, False, False, False] []
# of men. [False, True, False] [men]
# . [False] []
# done!
#                 younger  unaffected  rock  readiness  intimate  book  \
# younger               0           0     0          0         0     0
# unaffected            0           0     0          0         0     0
# rock                  0           0     0          0         0     0
# readiness             0           0     0          0         0     0
# intimate              0           0     0          0         0     0
# book                  0           0     0          0         0     0
# decencies             0           0     0          0         0     0
# men                   0           0     0          0         0     0
# suppressions          0           0     0          0         0     0
# moral                 0           0     0          0         0     0
# gift                  0           0     0          0         0     0
# privileged            0           0     0          0         0     0
# interest              0           0     0          0         0     0
# man                   0           0     0          0         0     0
# unmistakable          0           0     0          0         0     0
# judgments             0           0     0          0         0     0
# men                   0           0     0          0         0     0
# likely                0           0     0          0         0     0
# point                 0           0     0          0         0     0
# politician            0           0     0          0         0     0
# wild                  0           0     0          0         0     0
# responsiveness        0           0     0          0         0     0
# tolerance             0           0     0          0         0     0
# dignified             0           0     0          0         0     0
# successful            0           0     0          0         0     0
# limit                 0           0     0          0         0     0
# afraid                0           0     0          0         0     0
# dreams                0           0     0          0         0     0
# heart                 0           0     0          0         0     0
# levity                0           0     0          0         0     0
# ...                 ...         ...   ...        ...       ...   ...
# unknown               0           0     0          0         0     0
# bores                 0           0     0          0         0     0
# obvious               0           0     0          0         0     0
# years                 0           0     0          0         0     0
# personality           0           0     0          0         0     0
# Conduct               0           0     0          0         0     0
# extraordinary         0           0     0          0         0     0
# sensitivity           0           0     0          0         0     0
# marshes               0           0     0          0         0     0
# certain               0           0     0          0         0     0
# men                   0           0     0          0         0     0
# natures               0           0     0          0         0     0
# preoccupation         0           0     0          0         0     0
# little                0           0     0          0         0     0
# human                 0           0     0          0         0     0
# hostile               0           0     0          0         0     0
# normal                0           0     0          0         0     0
# sorrows               0           0     0          0         0     0
# intricate             0           0     0          0         0     0
# intimate              0           0     0          0         0     0
# revelations           0           0     0          0         0     0
# world                 0           0     0          0         0     0
# hope                  0           0     0          0         0     0
# father                0           0     0          0         0     0
# excursions            0           0     0          0         0     0
# quick                 0           0     0          0         0     0
# elations              0           0     0          0         0     0
# griefs                0           0     0          0         0     0
# reaction              0           0     0          0         0     0
# plagiaristic          0           0     0          0         0     0
#
#                 decencies  men  suppressions  moral      ...       \
# younger                 0    0             0      0      ...
# unaffected              0    0             0      0      ...
# rock                    0    0             0      0      ...
# readiness               0    0             0      0      ...
# intimate                0    0             0      0      ...
# book                    0    0             0      0      ...
# decencies               0    0             0      0      ...
# men                     0    0             0      0      ...
# suppressions            0    0             0      0      ...
# moral                   0    0             0      0      ...
# gift                    0    0             0      0      ...
# privileged              0    0             0      0      ...
# interest                0    0             0      0      ...
# man                     0    0             0      0      ...
# unmistakable            0    0             0      0      ...
# judgments               0    0             0      0      ...
# men                     0    0             0      0      ...
# likely                  0    0             0      0      ...
# point                   0    0             0      0      ...
# politician              0    0             0      0      ...
# wild                    0    1             0      0      ...
# responsiveness          0    0             0      0      ...
# tolerance               0    0             0      0      ...
# dignified               0    0             0      0      ...
# successful              0    0             0      0      ...
# limit                   0    0             0      0      ...
# afraid                  0    0             0      0      ...
# dreams                  0    0             0      0      ...
# heart                   0    0             0      0      ...
# levity                  0    0             0      0      ...
# ...                   ...  ...           ...    ...      ...
# unknown                 0    1             0      0      ...
# bores                   0    0             0      0      ...
# obvious                 0    0             1      0      ...
# years                   0    0             0      0      ...
# personality             0    0             0      0      ...
# Conduct                 0    0             0      0      ...
# extraordinary           0    0             0      0      ...
# sensitivity             0    0             0      0      ...
# marshes                 0    0             0      0      ...
# certain                 0    0             0      0      ...
# men                     0    0             0      0      ...
# natures                 0    0             0      0      ...
# preoccupation           0    0             0      0      ...
# little                  0    0             0      0      ...
# human                   0    0             0      0      ...
# hostile                 0    0             0      0      ...
# normal                  0    0             0      0      ...
# sorrows                 0    0             0      0      ...
# intricate               0    0             0      0      ...
# intimate                0    0             0      0      ...
# revelations             0    0             0      0      ...
# world                   0    0             0      0      ...
# hope                    0    0             0      0      ...
# father                  0    0             0      0      ...
# excursions              0    0             0      0      ...
# quick                   0    0             0      0      ...
# elations                0    0             0      0      ...
# griefs                  0    0             0      0      ...
# reaction                0    0             0      0      ...
# plagiaristic            0    0             0      0      ...
#
#                 revelations  world  hope  father  excursions  quick  elations  \
# younger                   0      0     0       0           0      0         0
# unaffected                0      0     0       0           0      0         0
# rock                      0      0     0       0           0      0         0
# readiness                 0      0     0       0           0      0         0
# intimate                  1      0     0       0           0      0         0
# book                      0      0     0       0           0      0         0
# decencies                 0      0     0       0           0      0         0
# men                       0      0     0       0           0      0         0
# suppressions              0      0     0       0           0      0         0
# moral                     0      0     0       0           0      0         0
# gift                      0      0     0       0           0      0         0
# privileged                0      0     0       0           0      0         0
# interest                  0      0     0       0           0      0         0
# man                       0      0     0       0           0      0         0
# unmistakable              0      0     0       0           0      0         0
# judgments                 0      0     0       0           0      0         0
# men                       0      0     0       0           0      0         0
# likely                    0      0     0       0           0      0         0
# point                     0      0     0       0           0      0         0
# politician                0      0     0       0           0      0         0
# wild                      0      0     0       0           0      0         0
# responsiveness            0      0     0       0           0      0         0
# tolerance                 0      0     0       0           0      0         0
# dignified                 0      0     0       0           0      0         0
# successful                0      0     0       0           0      0         0
# limit                     0      0     0       0           0      0         0
# afraid                    0      0     0       0           0      0         0
# dreams                    0      0     0       0           0      0         0
# heart                     0      0     0       0           0      0         0
# levity                    0      0     0       0           0      0         0
# ...                     ...    ...   ...     ...         ...    ...       ...
# unknown                   0      0     0       0           0      0         0
# bores                     0      0     0       0           0      0         0
# obvious                   0      0     0       0           0      0         0
# years                     0      0     0       1           0      0         0
# personality               0      0     0       0           0      0         0
# Conduct                   0      0     0       0           0      0         0
# extraordinary             0      0     0       0           0      0         0
# sensitivity               0      0     0       0           0      0         0
# marshes                   0      0     0       0           0      0         0
# certain                   0      0     0       0           0      0         0
# men                       0      0     0       0           0      0         0
# natures                   0      0     0       0           0      0         0
# preoccupation             0      0     0       0           0      0         0
# little                    0      0     0       0           0      0         0
# human                     0      0     0       0           0      0         0
# hostile                   0      0     0       0           0      0         0
# normal                    0      0     0       0           0      0         0
# sorrows                   0      0     0       0           0      0         0
# intricate                 0      0     0       0           0      0         0
# intimate                  0      0     0       0           0      0         0
# revelations               0      0     0       0           0      0         0
# world                     0      0     0       0           0      0         0
# hope                      0      0     0       0           0      0         0
# father                    0      0     0       0           0      0         0
# excursions                0      0     0       0           0      0         0
# quick                     0      0     0       0           0      0         0
# elations                  0      0     0       0           0      0         0
# griefs                    0      0     0       0           0      0         0
# reaction                  0      0     0       0           0      0         0
# plagiaristic              0      0     0       0           0      0         0
#
#                 griefs  reaction  plagiaristic
# younger              0         0             0
# unaffected           0         0             0
# rock                 0         0             0
# readiness            0         0             0
# intimate             0         0             0
# book                 0         0             0
# decencies            0         0             0
# men                  0         0             0
# suppressions         0         0             0
# moral                0         0             0
# gift                 0         0             0
# privileged           0         0             0
# interest             0         0             0
# man                  0         0             0
# unmistakable         0         0             0
# judgments            0         0             0
# men                  0         0             0
# likely               0         0             0
# point                0         0             0
# politician           0         0             0
# wild                 0         0             0
# responsiveness       0         0             0
# tolerance            0         0             0
# dignified            0         0             0
# successful           0         0             0
# limit                0         0             0
# afraid               0         0             0
# dreams               0         0             0
# heart                0         0             0
# levity               0         0             0
# ...                ...       ...           ...
# unknown              0         0             0
# bores                0         0             0
# obvious              0         0             0
# years                0         0             0
# personality          0         0             0
# Conduct              0         0             0
# extraordinary        0         0             0
# sensitivity          0         0             0
# marshes              0         0             0
# certain              0         0             0
# men                  0         0             0
# natures              0         0             0
# preoccupation        0         0             0
# little               0         0             0
# human                0         0             0
# hostile              0         0             0
# normal               0         0             0
# sorrows              0         0             0
# intricate            0         0             0
# intimate             0         0             0
# revelations          0         0             0
# world                0         0             0
# hope                 0         0             0
# father               0         0             0
# excursions           0         0             0
# quick                0         0             0
# elations             0         0             0
# griefs               0         0             0
# reaction             0         0             0
# plagiaristic         0         0             0
# [133 rows x 133 columns]

# %%
len(gatsby)
# Out:
# 554

# %%
demo = ['hey', 'you', 'over', 'there']
'you' in demo
for i in range(len(demo)):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
demo_df=pd.DataFrame(columns=demo,index=demo,data=0)

# %%
demo_df.loc['hey', 'hey'] = demo_df.loc['hey', 'hey']+1
demo_df.loc['hey', 'hey']
# Out:
# 1

# %%
for i,word in enumerate(gatsby):
    print(len(gatsby), max(0,len(gatsby)-(len(gatsby)-(i+20))))
# Out:
# 554 20
# 554 21
# 554 22
# 554 23
# 554 24
# 554 25
# 554 26
# 554 27
# 554 28
# 554 29
# 554 30
# 554 31
# 554 32
# 554 33
# 554 34
# 554 35
# 554 36
# 554 37
# 554 38
# 554 39
# 554 40
# 554 41
# 554 42
# 554 43
# 554 44
# 554 45
# 554 46
# 554 47
# 554 48
# 554 49
# 554 50
# 554 51
# 554 52
# 554 53
# 554 54
# 554 55
# 554 56
# 554 57
# 554 58
# 554 59
# 554 60
# 554 61
# 554 62
# 554 63
# 554 64
# 554 65
# 554 66
# 554 67
# 554 68
# 554 69
# 554 70
# 554 71
# 554 72
# 554 73
# 554 74
# 554 75
# 554 76
# 554 77
# 554 78
# 554 79
# 554 80
# 554 81
# 554 82
# 554 83
# 554 84
# 554 85
# 554 86
# 554 87
# 554 88
# 554 89
# 554 90
# 554 91
# 554 92
# 554 93
# 554 94
# 554 95
# 554 96
# 554 97
# 554 98
# 554 99
# 554 100
# 554 101
# 554 102
# 554 103
# 554 104
# 554 105
# 554 106
# 554 107
# 554 108
# 554 109
# 554 110
# 554 111
# 554 112
# 554 113
# 554 114
# 554 115
# 554 116
# 554 117
# 554 118
# 554 119
# 554 120
# 554 121
# 554 122
# 554 123
# 554 124
# 554 125
# 554 126
# 554 127
# 554 128
# 554 129
# 554 130
# 554 131
# 554 132
# 554 133
# 554 134
# 554 135
# 554 136
# 554 137
# 554 138
# 554 139
# 554 140
# 554 141
# 554 142
# 554 143
# 554 144
# 554 145
# 554 146
# 554 147
# 554 148
# 554 149
# 554 150
# 554 151
# 554 152
# 554 153
# 554 154
# 554 155
# 554 156
# 554 157
# 554 158
# 554 159
# 554 160
# 554 161
# 554 162
# 554 163
# 554 164
# 554 165
# 554 166
# 554 167
# 554 168
# 554 169
# 554 170
# 554 171
# 554 172
# 554 173
# 554 174
# 554 175
# 554 176
# 554 177
# 554 178
# 554 179
# 554 180
# 554 181
# 554 182
# 554 183
# 554 184
# 554 185
# 554 186
# 554 187
# 554 188
# 554 189
# 554 190
# 554 191
# 554 192
# 554 193
# 554 194
# 554 195
# 554 196
# 554 197
# 554 198
# 554 199
# 554 200
# 554 201
# 554 202
# 554 203
# 554 204
# 554 205
# 554 206
# 554 207
# 554 208
# 554 209
# 554 210
# 554 211
# 554 212
# 554 213
# 554 214
# 554 215
# 554 216
# 554 217
# 554 218
# 554 219
# 554 220
# 554 221
# 554 222
# 554 223
# 554 224
# 554 225
# 554 226
# 554 227
# 554 228
# 554 229
# 554 230
# 554 231
# 554 232
# 554 233
# 554 234
# 554 235
# 554 236
# 554 237
# 554 238
# 554 239
# 554 240
# 554 241
# 554 242
# 554 243
# 554 244
# 554 245
# 554 246
# 554 247
# 554 248
# 554 249
# 554 250
# 554 251
# 554 252
# 554 253
# 554 254
# 554 255
# 554 256
# 554 257
# 554 258
# 554 259
# 554 260
# 554 261
# 554 262
# 554 263
# 554 264
# 554 265
# 554 266
# 554 267
# 554 268
# 554 269
# 554 270
# 554 271
# 554 272
# 554 273
# 554 274
# 554 275
# 554 276
# 554 277
# 554 278
# 554 279
# 554 280
# 554 281
# 554 282
# 554 283
# 554 284
# 554 285
# 554 286
# 554 287
# 554 288
# 554 289
# 554 290
# 554 291
# 554 292
# 554 293
# 554 294
# 554 295
# 554 296
# 554 297
# 554 298
# 554 299
# 554 300
# 554 301
# 554 302
# 554 303
# 554 304
# 554 305
# 554 306
# 554 307
# 554 308
# 554 309
# 554 310
# 554 311
# 554 312
# 554 313
# 554 314
# 554 315
# 554 316
# 554 317
# 554 318
# 554 319
# 554 320
# 554 321
# 554 322
# 554 323
# 554 324
# 554 325
# 554 326
# 554 327
# 554 328
# 554 329
# 554 330
# 554 331
# 554 332
# 554 333
# 554 334
# 554 335
# 554 336
# 554 337
# 554 338
# 554 339
# 554 340
# 554 341
# 554 342
# 554 343
# 554 344
# 554 345
# 554 346
# 554 347
# 554 348
# 554 349
# 554 350
# 554 351
# 554 352
# 554 353
# 554 354
# 554 355
# 554 356
# 554 357
# 554 358
# 554 359
# 554 360
# 554 361
# 554 362
# 554 363
# 554 364
# 554 365
# 554 366
# 554 367
# 554 368
# 554 369
# 554 370
# 554 371
# 554 372
# 554 373
# 554 374
# 554 375
# 554 376
# 554 377
# 554 378
# 554 379
# 554 380
# 554 381
# 554 382
# 554 383
# 554 384
# 554 385
# 554 386
# 554 387
# 554 388
# 554 389
# 554 390
# 554 391
# 554 392
# 554 393
# 554 394
# 554 395
# 554 396
# 554 397
# 554 398
# 554 399
# 554 400
# 554 401
# 554 402
# 554 403
# 554 404
# 554 405
# 554 406
# 554 407
# 554 408
# 554 409
# 554 410
# 554 411
# 554 412
# 554 413
# 554 414
# 554 415
# 554 416
# 554 417
# 554 418
# 554 419
# 554 420
# 554 421
# 554 422
# 554 423
# 554 424
# 554 425
# 554 426
# 554 427
# 554 428
# 554 429
# 554 430
# 554 431
# 554 432
# 554 433
# 554 434
# 554 435
# 554 436
# 554 437
# 554 438
# 554 439
# 554 440
# 554 441
# 554 442
# 554 443
# 554 444
# 554 445
# 554 446
# 554 447
# 554 448
# 554 449
# 554 450
# 554 451
# 554 452
# 554 453
# 554 454
# 554 455
# 554 456
# 554 457
# 554 458
# 554 459
# 554 460
# 554 461
# 554 462
# 554 463
# 554 464
# 554 465
# 554 466
# 554 467
# 554 468
# 554 469
# 554 470
# 554 471
# 554 472
# 554 473
# 554 474
# 554 475
# 554 476
# 554 477
# 554 478
# 554 479
# 554 480
# 554 481
# 554 482
# 554 483
# 554 484
# 554 485
# 554 486
# 554 487
# 554 488
# 554 489
# 554 490
# 554 491
# 554 492
# 554 493
# 554 494
# 554 495
# 554 496
# 554 497
# 554 498
# 554 499
# 554 500
# 554 501
# 554 502
# 554 503
# 554 504
# 554 505
# 554 506
# 554 507
# 554 508
# 554 509
# 554 510
# 554 511
# 554 512
# 554 513
# 554 514
# 554 515
# 554 516
# 554 517
# 554 518
# 554 519
# 554 520
# 554 521
# 554 522
# 554 523
# 554 524
# 554 525
# 554 526
# 554 527
# 554 528
# 554 529
# 554 530
# 554 531
# 554 532
# 554 533
# 554 534
# 554 535
# 554 536
# 554 537
# 554 538
# 554 539
# 554 540
# 554 541
# 554 542
# 554 543
# 554 544
# 554 545
# 554 546
# 554 547
# 554 548
# 554 549
# 554 550
# 554 551
# 554 552
# 554 553
# 554 554
# 554 555
# 554 556
# 554 557
# 554 558
# 554 559
# 554 560
# 554 561
# 554 562
# 554 563
# 554 564
# 554 565
# 554 566
# 554 567
# 554 568
# 554 569
# 554 570
# 554 571
# 554 572
# 554 573

# %%
for item in gatsby_filt:
    print(item)
# Out:
# younger
# vulnerable
# years
# father
# advice
# mind
# people
# world
# advantages
# communicative
# reserved
# way
# great
# deal
# consequence
# inclined
# judgments
# habit
# curious
# natures
# victim
# veteran
# bores
# abnormal
# mind
# quick
# quality
# normal
# person
# college
# politician
# privy
# secret
# griefs
# wild
# unknown
# men
# Most
# confidences
# sleep
# preoccupation
# hostile
# levity
# unmistakable
# sign
# intimate
# revelation
# horizon
# intimate
# revelations
# young
# men
# terms
# plagiaristic
# obvious
# suppressions
# Reserving
# judgments
# matter
# infinite
# hope
# little
# afraid
# father
# sense
# fundamental
# decencies
# birth
# way
# tolerance
# admission
# limit
# Conduct
# hard
# rock
# wet
# marshes
# certain
# point
# autumn
# world
# uniform
# sort
# moral
# attention
# riotous
# excursions
# privileged
# glimpses
# human
# heart
# man
# book
# exempt
# reaction
# unaffected
# scorn
# personality
# unbroken
# series
# successful
# gestures
# gorgeous
# sensitivity
# promises
# life
# intricate
# machines
# earthquakes
# miles
# responsiveness
# flabby
# impressionability
# dignified
# creative
# temperament
# extraordinary
# gift
# hope
# romantic
# readiness
# person
# likely
# end
# foul
# dust
# wake
# dreams
# interest
# abortive
# sorrows
# elations
# men

# %%
# Running TextRank
nx_words = nx.from_numpy_matrix(adjacency.as_matrix())
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(words)),
                reverse=True)
print(ranked[:5])
# Out:
# C:\Users\Loren\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(0.013370948308795436, hope), (0.012223431176324349, promises), (0.012223431176324349, exempt), (0.012142068850548908, glimpses), (0.011895137937387881, intimate)]

# %% [markdown]
# These results are less impressive.  'Hope', 'promises', and 'glimpses' certainly fit the elegiac, on-the-outside-looking-in tone of the book, but 'exempt' and 'world' are pretty generic.  TextRank may perform better on a larger text sample.
#
# # Drill
#
# It is also possible that keyword phrases will work better.  Modfiy the keyword extraction code to extract two-word phrases (digrams) rather than single words.  Then try it with trigrams.  You will probably want to broaden the window that defines 'neighbors.'  Try a few different modifications, and write up your observations in your notebook.  Discuss with your mentor.

# %%
# build bigrams from gatsby_filt
bigrams = set()
prev_word = gatsby_filt[0]
for i in range (1,len(gatsby_filt)):
    bigrams.add(str(prev_word)+"-"+str(gatsby_filt[i]))
    prev_word = gatsby_filt[i]
  

  
adjacency=pd.DataFrame(columns=bigrams,index=bigrams,data=0)  
print(adjacency)
# Out:
#                              book-exempt  Reserving-judgments  \
# book-exempt                            0                    0
# Reserving-judgments                    0                    0
# politician-privy                       0                    0
# Conduct-hard                           0                    0
# foul-dust                              0                    0
# creative-temperament                   0                    0
# man-book                               0                    0
# habit-curious                          0                    0
# inclined-judgments                     0                    0
# obvious-suppressions                   0                    0
# younger-vulnerable                     0                    0
# sleep-preoccupation                    0                    0
# suppressions-Reserving                 0                    0
# personality-unbroken                   0                    0
# intricate-machines                     0                    0
# mind-quick                             0                    0
# reserved-way                           0                    0
# father-sense                           0                    0
# gorgeous-sensitivity                   0                    0
# unaffected-scorn                       0                    0
# intimate-revelation                    0                    0
# wake-dreams                            0                    0
# matter-infinite                        0                    0
# fundamental-decencies                  0                    0
# unbroken-series                        0                    0
# vulnerable-years                       0                    0
# hostile-levity                         0                    0
# judgments-habit                        0                    0
# hard-rock                              0                    0
# curious-natures                        0                    0
# ...                                  ...                  ...
# readiness-person                       0                    0
# abortive-sorrows                       0                    0
# point-autumn                           0                    0
# flabby-impressionability               0                    0
# infinite-hope                          0                    0
# natures-victim                         0                    0
# horizon-intimate                       0                    0
# impressionability-dignified            0                    0
# privy-secret                           0                    0
# hope-romantic                          0                    0
# intimate-revelations                   0                    0
# Most-confidences                       0                    0
# advice-mind                            0                    0
# wet-marshes                            0                    0
# years-father                           0                    0
# preoccupation-hostile                  0                    0
# interest-abortive                      0                    0
# human-heart                            0                    0
# communicative-reserved                 0                    0
# world-advantages                       0                    0
# plagiaristic-obvious                   0                    0
# way-tolerance                          0                    0
# confidences-sleep                      0                    0
# unmistakable-sign                      0                    0
# revelations-young                      0                    0
# end-foul                               0                    0
# sign-intimate                          0                    0
# privileged-glimpses                    0                    0
# uniform-sort                           0                    0
# sense-fundamental                      0                    0
#
#                              politician-privy  Conduct-hard  foul-dust  \
# book-exempt                                 0             0          0
# Reserving-judgments                         0             0          0
# politician-privy                            0             0          0
# Conduct-hard                                0             0          0
# foul-dust                                   0             0          0
# creative-temperament                        0             0          0
# man-book                                    0             0          0
# habit-curious                               0             0          0
# inclined-judgments                          0             0          0
# obvious-suppressions                        0             0          0
# younger-vulnerable                          0             0          0
# sleep-preoccupation                         0             0          0
# suppressions-Reserving                      0             0          0
# personality-unbroken                        0             0          0
# intricate-machines                          0             0          0
# mind-quick                                  0             0          0
# reserved-way                                0             0          0
# father-sense                                0             0          0
# gorgeous-sensitivity                        0             0          0
# unaffected-scorn                            0             0          0
# intimate-revelation                         0             0          0
# wake-dreams                                 0             0          0
# matter-infinite                             0             0          0
# fundamental-decencies                       0             0          0
# unbroken-series                             0             0          0
# vulnerable-years                            0             0          0
# hostile-levity                              0             0          0
# judgments-habit                             0             0          0
# hard-rock                                   0             0          0
# curious-natures                             0             0          0
# ...                                       ...           ...        ...
# readiness-person                            0             0          0
# abortive-sorrows                            0             0          0
# point-autumn                                0             0          0
# flabby-impressionability                    0             0          0
# infinite-hope                               0             0          0
# natures-victim                              0             0          0
# horizon-intimate                            0             0          0
# impressionability-dignified                 0             0          0
# privy-secret                                0             0          0
# hope-romantic                               0             0          0
# intimate-revelations                        0             0          0
# Most-confidences                            0             0          0
# advice-mind                                 0             0          0
# wet-marshes                                 0             0          0
# years-father                                0             0          0
# preoccupation-hostile                       0             0          0
# interest-abortive                           0             0          0
# human-heart                                 0             0          0
# communicative-reserved                      0             0          0
# world-advantages                            0             0          0
# plagiaristic-obvious                        0             0          0
# way-tolerance                               0             0          0
# confidences-sleep                           0             0          0
# unmistakable-sign                           0             0          0
# revelations-young                           0             0          0
# end-foul                                    0             0          0
# sign-intimate                               0             0          0
# privileged-glimpses                         0             0          0
# uniform-sort                                0             0          0
# sense-fundamental                           0             0          0
#
#                              creative-temperament  man-book  habit-curious  \
# book-exempt                                     0         0              0
# Reserving-judgments                             0         0              0
# politician-privy                                0         0              0
# Conduct-hard                                    0         0              0
# foul-dust                                       0         0              0
# creative-temperament                            0         0              0
# man-book                                        0         0              0
# habit-curious                                   0         0              0
# inclined-judgments                              0         0              0
# obvious-suppressions                            0         0              0
# younger-vulnerable                              0         0              0
# sleep-preoccupation                             0         0              0
# suppressions-Reserving                          0         0              0
# personality-unbroken                            0         0              0
# intricate-machines                              0         0              0
# mind-quick                                      0         0              0
# reserved-way                                    0         0              0
# father-sense                                    0         0              0
# gorgeous-sensitivity                            0         0              0
# unaffected-scorn                                0         0              0
# intimate-revelation                             0         0              0
# wake-dreams                                     0         0              0
# matter-infinite                                 0         0              0
# fundamental-decencies                           0         0              0
# unbroken-series                                 0         0              0
# vulnerable-years                                0         0              0
# hostile-levity                                  0         0              0
# judgments-habit                                 0         0              0
# hard-rock                                       0         0              0
# curious-natures                                 0         0              0
# ...                                           ...       ...            ...
# readiness-person                                0         0              0
# abortive-sorrows                                0         0              0
# point-autumn                                    0         0              0
# flabby-impressionability                        0         0              0
# infinite-hope                                   0         0              0
# natures-victim                                  0         0              0
# horizon-intimate                                0         0              0
# impressionability-dignified                     0         0              0
# privy-secret                                    0         0              0
# hope-romantic                                   0         0              0
# intimate-revelations                            0         0              0
# Most-confidences                                0         0              0
# advice-mind                                     0         0              0
# wet-marshes                                     0         0              0
# years-father                                    0         0              0
# preoccupation-hostile                           0         0              0
# interest-abortive                               0         0              0
# human-heart                                     0         0              0
# communicative-reserved                          0         0              0
# world-advantages                                0         0              0
# plagiaristic-obvious                            0         0              0
# way-tolerance                                   0         0              0
# confidences-sleep                               0         0              0
# unmistakable-sign                               0         0              0
# revelations-young                               0         0              0
# end-foul                                        0         0              0
# sign-intimate                                   0         0              0
# privileged-glimpses                             0         0              0
# uniform-sort                                    0         0              0
# sense-fundamental                               0         0              0
#
#                              inclined-judgments  obvious-suppressions  \
# book-exempt                                   0                     0
# Reserving-judgments                           0                     0
# politician-privy                              0                     0
# Conduct-hard                                  0                     0
# foul-dust                                     0                     0
# creative-temperament                          0                     0
# man-book                                      0                     0
# habit-curious                                 0                     0
# inclined-judgments                            0                     0
# obvious-suppressions                          0                     0
# younger-vulnerable                            0                     0
# sleep-preoccupation                           0                     0
# suppressions-Reserving                        0                     0
# personality-unbroken                          0                     0
# intricate-machines                            0                     0
# mind-quick                                    0                     0
# reserved-way                                  0                     0
# father-sense                                  0                     0
# gorgeous-sensitivity                          0                     0
# unaffected-scorn                              0                     0
# intimate-revelation                           0                     0
# wake-dreams                                   0                     0
# matter-infinite                               0                     0
# fundamental-decencies                         0                     0
# unbroken-series                               0                     0
# vulnerable-years                              0                     0
# hostile-levity                                0                     0
# judgments-habit                               0                     0
# hard-rock                                     0                     0
# curious-natures                               0                     0
# ...                                         ...                   ...
# readiness-person                              0                     0
# abortive-sorrows                              0                     0
# point-autumn                                  0                     0
# flabby-impressionability                      0                     0
# infinite-hope                                 0                     0
# natures-victim                                0                     0
# horizon-intimate                              0                     0
# impressionability-dignified                   0                     0
# privy-secret                                  0                     0
# hope-romantic                                 0                     0
# intimate-revelations                          0                     0
# Most-confidences                              0                     0
# advice-mind                                   0                     0
# wet-marshes                                   0                     0
# years-father                                  0                     0
# preoccupation-hostile                         0                     0
# interest-abortive                             0                     0
# human-heart                                   0                     0
# communicative-reserved                        0                     0
# world-advantages                              0                     0
# plagiaristic-obvious                          0                     0
# way-tolerance                                 0                     0
# confidences-sleep                             0                     0
# unmistakable-sign                             0                     0
# revelations-young                             0                     0
# end-foul                                      0                     0
# sign-intimate                                 0                     0
# privileged-glimpses                           0                     0
# uniform-sort                                  0                     0
# sense-fundamental                             0                     0
#
#                                    ...          plagiaristic-obvious  \
# book-exempt                        ...                             0
# Reserving-judgments                ...                             0
# politician-privy                   ...                             0
# Conduct-hard                       ...                             0
# foul-dust                          ...                             0
# creative-temperament               ...                             0
# man-book                           ...                             0
# habit-curious                      ...                             0
# inclined-judgments                 ...                             0
# obvious-suppressions               ...                             0
# younger-vulnerable                 ...                             0
# sleep-preoccupation                ...                             0
# suppressions-Reserving             ...                             0
# personality-unbroken               ...                             0
# intricate-machines                 ...                             0
# mind-quick                         ...                             0
# reserved-way                       ...                             0
# father-sense                       ...                             0
# gorgeous-sensitivity               ...                             0
# unaffected-scorn                   ...                             0
# intimate-revelation                ...                             0
# wake-dreams                        ...                             0
# matter-infinite                    ...                             0
# fundamental-decencies              ...                             0
# unbroken-series                    ...                             0
# vulnerable-years                   ...                             0
# hostile-levity                     ...                             0
# judgments-habit                    ...                             0
# hard-rock                          ...                             0
# curious-natures                    ...                             0
# ...                                ...                           ...
# readiness-person                   ...                             0
# abortive-sorrows                   ...                             0
# point-autumn                       ...                             0
# flabby-impressionability           ...                             0
# infinite-hope                      ...                             0
# natures-victim                     ...                             0
# horizon-intimate                   ...                             0
# impressionability-dignified        ...                             0
# privy-secret                       ...                             0
# hope-romantic                      ...                             0
# intimate-revelations               ...                             0
# Most-confidences                   ...                             0
# advice-mind                        ...                             0
# wet-marshes                        ...                             0
# years-father                       ...                             0
# preoccupation-hostile              ...                             0
# interest-abortive                  ...                             0
# human-heart                        ...                             0
# communicative-reserved             ...                             0
# world-advantages                   ...                             0
# plagiaristic-obvious               ...                             0
# way-tolerance                      ...                             0
# confidences-sleep                  ...                             0
# unmistakable-sign                  ...                             0
# revelations-young                  ...                             0
# end-foul                           ...                             0
# sign-intimate                      ...                             0
# privileged-glimpses                ...                             0
# uniform-sort                       ...                             0
# sense-fundamental                  ...                             0
#
#                              way-tolerance  confidences-sleep  \
# book-exempt                              0                  0
# Reserving-judgments                      0                  0
# politician-privy                         0                  0
# Conduct-hard                             0                  0
# foul-dust                                0                  0
# creative-temperament                     0                  0
# man-book                                 0                  0
# habit-curious                            0                  0
# inclined-judgments                       0                  0
# obvious-suppressions                     0                  0
# younger-vulnerable                       0                  0
# sleep-preoccupation                      0                  0
# suppressions-Reserving                   0                  0
# personality-unbroken                     0                  0
# intricate-machines                       0                  0
# mind-quick                               0                  0
# reserved-way                             0                  0
# father-sense                             0                  0
# gorgeous-sensitivity                     0                  0
# unaffected-scorn                         0                  0
# intimate-revelation                      0                  0
# wake-dreams                              0                  0
# matter-infinite                          0                  0
# fundamental-decencies                    0                  0
# unbroken-series                          0                  0
# vulnerable-years                         0                  0
# hostile-levity                           0                  0
# judgments-habit                          0                  0
# hard-rock                                0                  0
# curious-natures                          0                  0
# ...                                    ...                ...
# readiness-person                         0                  0
# abortive-sorrows                         0                  0
# point-autumn                             0                  0
# flabby-impressionability                 0                  0
# infinite-hope                            0                  0
# natures-victim                           0                  0
# horizon-intimate                         0                  0
# impressionability-dignified              0                  0
# privy-secret                             0                  0
# hope-romantic                            0                  0
# intimate-revelations                     0                  0
# Most-confidences                         0                  0
# advice-mind                              0                  0
# wet-marshes                              0                  0
# years-father                             0                  0
# preoccupation-hostile                    0                  0
# interest-abortive                        0                  0
# human-heart                              0                  0
# communicative-reserved                   0                  0
# world-advantages                         0                  0
# plagiaristic-obvious                     0                  0
# way-tolerance                            0                  0
# confidences-sleep                        0                  0
# unmistakable-sign                        0                  0
# revelations-young                        0                  0
# end-foul                                 0                  0
# sign-intimate                            0                  0
# privileged-glimpses                      0                  0
# uniform-sort                             0                  0
# sense-fundamental                        0                  0
#
#                              unmistakable-sign  revelations-young  end-foul  \
# book-exempt                                  0                  0         0
# Reserving-judgments                          0                  0         0
# politician-privy                             0                  0         0
# Conduct-hard                                 0                  0         0
# foul-dust                                    0                  0         0
# creative-temperament                         0                  0         0
# man-book                                     0                  0         0
# habit-curious                                0                  0         0
# inclined-judgments                           0                  0         0
# obvious-suppressions                         0                  0         0
# younger-vulnerable                           0                  0         0
# sleep-preoccupation                          0                  0         0
# suppressions-Reserving                       0                  0         0
# personality-unbroken                         0                  0         0
# intricate-machines                           0                  0         0
# mind-quick                                   0                  0         0
# reserved-way                                 0                  0         0
# father-sense                                 0                  0         0
# gorgeous-sensitivity                         0                  0         0
# unaffected-scorn                             0                  0         0
# intimate-revelation                          0                  0         0
# wake-dreams                                  0                  0         0
# matter-infinite                              0                  0         0
# fundamental-decencies                        0                  0         0
# unbroken-series                              0                  0         0
# vulnerable-years                             0                  0         0
# hostile-levity                               0                  0         0
# judgments-habit                              0                  0         0
# hard-rock                                    0                  0         0
# curious-natures                              0                  0         0
# ...                                        ...                ...       ...
# readiness-person                             0                  0         0
# abortive-sorrows                             0                  0         0
# point-autumn                                 0                  0         0
# flabby-impressionability                     0                  0         0
# infinite-hope                                0                  0         0
# natures-victim                               0                  0         0
# horizon-intimate                             0                  0         0
# impressionability-dignified                  0                  0         0
# privy-secret                                 0                  0         0
# hope-romantic                                0                  0         0
# intimate-revelations                         0                  0         0
# Most-confidences                             0                  0         0
# advice-mind                                  0                  0         0
# wet-marshes                                  0                  0         0
# years-father                                 0                  0         0
# preoccupation-hostile                        0                  0         0
# interest-abortive                            0                  0         0
# human-heart                                  0                  0         0
# communicative-reserved                       0                  0         0
# world-advantages                             0                  0         0
# plagiaristic-obvious                         0                  0         0
# way-tolerance                                0                  0         0
# confidences-sleep                            0                  0         0
# unmistakable-sign                            0                  0         0
# revelations-young                            0                  0         0
# end-foul                                     0                  0         0
# sign-intimate                                0                  0         0
# privileged-glimpses                          0                  0         0
# uniform-sort                                 0                  0         0
# sense-fundamental                            0                  0         0
#
#                              sign-intimate  privileged-glimpses  uniform-sort  \
# book-exempt                              0                    0             0
# Reserving-judgments                      0                    0             0
# politician-privy                         0                    0             0
# Conduct-hard                             0                    0             0
# foul-dust                                0                    0             0
# creative-temperament                     0                    0             0
# man-book                                 0                    0             0
# habit-curious                            0                    0             0
# inclined-judgments                       0                    0             0
# obvious-suppressions                     0                    0             0
# younger-vulnerable                       0                    0             0
# sleep-preoccupation                      0                    0             0
# suppressions-Reserving                   0                    0             0
# personality-unbroken                     0                    0             0
# intricate-machines                       0                    0             0
# mind-quick                               0                    0             0
# reserved-way                             0                    0             0
# father-sense                             0                    0             0
# gorgeous-sensitivity                     0                    0             0
# unaffected-scorn                         0                    0             0
# intimate-revelation                      0                    0             0
# wake-dreams                              0                    0             0
# matter-infinite                          0                    0             0
# fundamental-decencies                    0                    0             0
# unbroken-series                          0                    0             0
# vulnerable-years                         0                    0             0
# hostile-levity                           0                    0             0
# judgments-habit                          0                    0             0
# hard-rock                                0                    0             0
# curious-natures                          0                    0             0
# ...                                    ...                  ...           ...
# readiness-person                         0                    0             0
# abortive-sorrows                         0                    0             0
# point-autumn                             0                    0             0
# flabby-impressionability                 0                    0             0
# infinite-hope                            0                    0             0
# natures-victim                           0                    0             0
# horizon-intimate                         0                    0             0
# impressionability-dignified              0                    0             0
# privy-secret                             0                    0             0
# hope-romantic                            0                    0             0
# intimate-revelations                     0                    0             0
# Most-confidences                         0                    0             0
# advice-mind                              0                    0             0
# wet-marshes                              0                    0             0
# years-father                             0                    0             0
# preoccupation-hostile                    0                    0             0
# interest-abortive                        0                    0             0
# human-heart                              0                    0             0
# communicative-reserved                   0                    0             0
# world-advantages                         0                    0             0
# plagiaristic-obvious                     0                    0             0
# way-tolerance                            0                    0             0
# confidences-sleep                        0                    0             0
# unmistakable-sign                        0                    0             0
# revelations-young                        0                    0             0
# end-foul                                 0                    0             0
# sign-intimate                            0                    0             0
# privileged-glimpses                      0                    0             0
# uniform-sort                             0                    0             0
# sense-fundamental                        0                    0             0
#
#                              sense-fundamental
# book-exempt                                  0
# Reserving-judgments                          0
# politician-privy                             0
# Conduct-hard                                 0
# foul-dust                                    0
# creative-temperament                         0
# man-book                                     0
# habit-curious                                0
# inclined-judgments                           0
# obvious-suppressions                         0
# younger-vulnerable                           0
# sleep-preoccupation                          0
# suppressions-Reserving                       0
# personality-unbroken                         0
# intricate-machines                           0
# mind-quick                                   0
# reserved-way                                 0
# father-sense                                 0
# gorgeous-sensitivity                         0
# unaffected-scorn                             0
# intimate-revelation                          0
# wake-dreams                                  0
# matter-infinite                              0
# fundamental-decencies                        0
# unbroken-series                              0
# vulnerable-years                             0
# hostile-levity                               0
# judgments-habit                              0
# hard-rock                                    0
# curious-natures                              0
# ...                                        ...
# readiness-person                             0
# abortive-sorrows                             0
# point-autumn                                 0
# flabby-impressionability                     0
# infinite-hope                                0
# natures-victim                               0
# horizon-intimate                             0
# impressionability-dignified                  0
# privy-secret                                 0
# hope-romantic                                0
# intimate-revelations                         0
# Most-confidences                             0
# advice-mind                                  0
# wet-marshes                                  0
# years-father                                 0
# preoccupation-hostile                        0
# interest-abortive                            0
# human-heart                                  0
# communicative-reserved                       0
# world-advantages                             0
# plagiaristic-obvious                         0
# way-tolerance                                0
# confidences-sleep                            0
# unmistakable-sign                            0
# revelations-young                            0
# end-foul                                     0
# sign-intimate                                0
# privileged-glimpses                          0
# uniform-sort                                 0
# sense-fundamental                            0
# [132 rows x 132 columns]

# %%
# Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby):
    if i == 553:
        break
    bigram = str(word)+'-'+str(gatsby[i+1])
    # Checking if any of the word's next four neighbors are in the word list 
    if any([bigram == item for item in bigrams]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby)-(len(gatsby)-(i+10)))
        # The potential neighbors.
        nextwords=gatsby[i+1:end]
        # Filtering the neighbors to select only those in the word list
        nextgrams = []
        prev_word = nextwords[0]
        for i in range (1,len(nextwords)):
            nextgrams.append(str(prev_word)+"-"+str(nextwords[i]))
            prev_word = nextwords[i]
        
        
        inset=[x in bigrams for x in nextgrams]
        neighbors=[nextgrams[i] for i in range(len(nextgrams)) if inset[i]]
        print(nextgrams, inset, neighbors)
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            #Access a group of rows and columns by label(s) or a boolean array. 
            adjacency.loc[bigram,neighbors]=adjacency.loc[bigram,neighbors]+1
# Out:
# ['years-my', 'my-father', 'father-gave', 'gave-me', 'me-some', 'some-advice', 'advice-that', 'that-I'] [False, False, False, False, False, False, False, False] []
# ['way-,', ',-and', 'and-I', 'I-understood', 'understood-that', 'that-he', 'he-meant', 'meant-a'] [False, False, False, False, False, False, False, False] []
# ['deal-more', 'more-than', 'than-that', 'that-.', '.-In', 'In-consequence', 'consequence-I', "I-'m"] [False, False, False, False, False, False, False, False] []
# ['natures-to', 'to-me', 'me-and', 'and-also', 'also-made', 'made-me', 'me-the', 'the-victim'] [False, False, False, False, False, False, False, False] []
# ['bores-.', '.-The', 'The-abnormal', 'abnormal-mind', 'mind-is', 'is-quick', 'quick-to', 'to-detect'] [False, False, False, True, False, False, False, False] ['abnormal-mind']
# ['mind-is', 'is-quick', 'quick-to', 'to-detect', 'detect-and', 'and-attach', 'attach-itself', 'itself-to'] [False, False, False, False, False, False, False, False] []
# ['person-,', ',-and', 'and-so', 'so-it', 'it-came', 'came-about', 'about-that', 'that-in'] [False, False, False, False, False, False, False, False] []
# ['griefs-of', 'of-wild', 'wild-,', ',-unknown', 'unknown-men', 'men-.', '.-Most', 'Most-of'] [False, False, False, False, True, False, False, False] ['unknown-men']
# ['men-.', '.-Most', 'Most-of', 'of-the', 'the-confidences', 'confidences-were', 'were-unsought', 'unsought---'] [False, False, False, False, False, False, False, False] []
# ['levity-when', 'when-I', 'I-realized', 'realized-by', 'by-some', 'some-unmistakable', 'unmistakable-sign', 'sign-that'] [False, False, False, False, False, False, True, False] ['unmistakable-sign']
# ['sign-that', 'that-an', 'an-intimate', 'intimate-revelation', 'revelation-was', 'was-quivering', 'quivering-on', 'on-the'] [False, False, False, True, False, False, False, False] ['intimate-revelation']
# ['revelation-was', 'was-quivering', 'quivering-on', 'on-the', 'the-horizon', 'horizon---', '---for', 'for-the'] [False, False, False, False, False, False, False, False] []
# ['revelations-of', 'of-young', 'young-men', 'men-or', 'or-at', 'at-least', 'least-the', 'the-terms'] [False, False, True, False, False, False, False, False] ['young-men']
# ['men-or', 'or-at', 'at-least', 'least-the', 'the-terms', 'terms-in', 'in-which', 'which-they'] [False, False, False, False, False, False, False, False] []
# ['suppressions-.', '.-Reserving', 'Reserving-judgments', 'judgments-is', 'is-a', 'a-matter', 'matter-of', 'of-infinite'] [False, False, True, False, False, False, False, False] ['Reserving-judgments']
# ['judgments-is', 'is-a', 'a-matter', 'matter-of', 'of-infinite', 'infinite-hope', 'hope-.', '.-I'] [False, False, False, False, False, True, False, False] ['infinite-hope']
# ['hope-.', '.-I', 'I-am', 'am-still', 'still-a', 'a-little', 'little-afraid', 'afraid-of'] [False, False, False, False, False, False, True, False] ['little-afraid']
# ['afraid-of', 'of-missing', 'missing-something', 'something-if', 'if-I', 'I-forget', 'forget-that', 'that-,'] [False, False, False, False, False, False, False, False] []
# ['decencies-is', 'is-parcelled', 'parcelled-out', 'out-unequally', 'unequally-at', 'at-birth', 'birth-.', '.-And'] [False, False, False, False, False, False, False, False] []
# ['rock-or', 'or-the', 'the-wet', 'wet-marshes', 'marshes-but', 'but-after', 'after-a', 'a-certain'] [False, False, False, True, False, False, False, False] ['wet-marshes']
# ['marshes-but', 'but-after', 'after-a', 'a-certain', 'certain-point', 'point-I', 'I-do', "do-n't"] [False, False, False, False, True, False, False, False] ['certain-point']
# ['point-I', 'I-do', "do-n't", "n't-care", 'care-what', 'what-it', "it-'s", "'s-founded"] [False, False, False, False, False, False, False, False] []
# ['attention-forever', 'forever-;', ';-I', 'I-wanted', 'wanted-no', 'no-more', 'more-riotous', 'riotous-excursions'] [False, False, False, False, False, False, False, True] ['riotous-excursions']
# ['excursions-with', 'with-privileged', 'privileged-glimpses', 'glimpses-into', 'into-the', 'the-human', 'human-heart', 'heart-.'] [False, False, True, False, False, False, True, False] ['privileged-glimpses', 'human-heart']
# ['glimpses-into', 'into-the', 'the-human', 'human-heart', 'heart-.', '.-Only', 'Only-Gatsby', 'Gatsby-,'] [False, False, False, True, False, False, False, False] ['human-heart']
# ['heart-.', '.-Only', 'Only-Gatsby', 'Gatsby-,', ',-the', 'the-man', 'man-who', 'who-gives'] [False, False, False, False, False, False, False, False] []
# ['scorn-.', '.-If', 'If-personality', 'personality-is', 'is-an', 'an-unbroken', 'unbroken-series', 'series-of'] [False, False, False, False, False, False, True, False] ['unbroken-series']
# ['series-of', 'of-successful', 'successful-gestures', 'gestures-,', ',-then', 'then-there', 'there-was', 'was-something'] [False, False, True, False, False, False, False, False] ['successful-gestures']
# ['gestures-,', ',-then', 'then-there', 'there-was', 'was-something', 'something-gorgeous', 'gorgeous-about', 'about-him'] [False, False, False, False, False, False, False, False] []
# ['machines-that', 'that-register', 'register-earthquakes', 'earthquakes-ten', 'ten-thousand', 'thousand-miles', 'miles-away', 'away-.'] [False, False, False, False, False, False, False, False] []
# ['impressionability-which', 'which-is', 'is-dignified', 'dignified-under', 'under-the', 'the-name', 'name-of', 'of-the'] [False, False, False, False, False, False, False, False] []
# ['temperament-"--', '"---it', 'it-was', 'was-an', 'an-extraordinary', 'extraordinary-gift', 'gift-for', 'for-hope'] [False, False, False, False, False, True, False, False] ['extraordinary-gift']
# ['gift-for', 'for-hope', 'hope-,', ',-a', 'a-romantic', 'romantic-readiness', 'readiness-such', 'such-as'] [False, False, False, False, False, True, False, False] ['romantic-readiness']
# ['readiness-such', 'such-as', 'as-I', 'I-have', 'have-never', 'never-found', 'found-in', 'in-any'] [False, False, False, False, False, False, False, False] []
# ['dust-floated', 'floated-in', 'in-the', 'the-wake', 'wake-of', 'of-his', 'his-dreams', 'dreams-that'] [False, False, False, False, False, False, False, False] []
# ['sorrows-and', 'and-short', 'short--', '--winded', 'winded-elations', 'elations-of', 'of-men', 'men-.'] [False, False, False, False, False, False, False, False] []

# %%
for i, word in enumerate(gatsby):
    bigram = str(word)+'-'+str(gatsby[i+1])
# Out:
# In-my
# my-younger
# younger-and
# and-more
# more-vulnerable
# vulnerable-years
# years-my
# my-father
# father-gave
# gave-me
# me-some
# some-advice
# advice-that
# that-I
# I-'ve
# 've-been
# been-turning
# turning-over
# over-in
# in-my
# my-mind
# mind-ever
# ever-since
# since-.
# .-"
# "-Whenever
# Whenever-you
# you-feel
# feel-like
# like-criticizing
# criticizing-any
# any-one
# one-,
# ,-"
# "-he
# he-told
# told-me
# me-,
# ,-"
# "-just
# just-remember
# remember-that
# that-all
# all-the
# the-people
# people-in
# in-this
# this-world
# world-have
# have-n't
# n't-had
# had-the
# the-advantages
# advantages-that
# that-you
# you-'ve
# 've-had
# had-.
# .-"
# "-He
# He-did
# did-n't
# n't-say
# say-any
# any-more
# more-but
# but-we
# we-'ve
# 've-always
# always-been
# been-unusually
# unusually-communicative
# communicative-in
# in-a
# a-reserved
# reserved-way
# way-,
# ,-and
# and-I
# I-understood
# understood-that
# that-he
# he-meant
# meant-a
# a-great
# great-deal
# deal-more
# more-than
# than-that
# that-.
# .-In
# In-consequence
# consequence-I
# I-'m
# 'm-inclined
# inclined-to
# to-reserve
# reserve-all
# all-judgments
# judgments-,
# ,-a
# a-habit
# habit-that
# that-has
# has-opened
# opened-up
# up-many
# many-curious
# curious-natures
# natures-to
# to-me
# me-and
# and-also
# also-made
# made-me
# me-the
# the-victim
# victim-of
# of-not
# not-a
# a-few
# few-veteran
# veteran-bores
# bores-.
# .-The
# The-abnormal
# abnormal-mind
# mind-is
# is-quick
# quick-to
# to-detect
# detect-and
# and-attach
# attach-itself
# itself-to
# to-this
# this-quality
# quality-when
# when-it
# it-appears
# appears-in
# in-a
# a-normal
# normal-person
# person-,
# ,-and
# and-so
# so-it
# it-came
# came-about
# about-that
# that-in
# in-college
# college-I
# I-was
# was-unjustly
# unjustly-accused
# accused-of
# of-being
# being-a
# a-politician
# politician-,
# ,-because
# because-I
# I-was
# was-privy
# privy-to
# to-the
# the-secret
# secret-griefs
# griefs-of
# of-wild
# wild-,
# ,-unknown
# unknown-men
# men-.
# .-Most
# Most-of
# of-the
# the-confidences
# confidences-were
# were-unsought
# unsought---
# ---frequently
# frequently-I
# I-have
# have-feigned
# feigned-sleep
# sleep-,
# ,-preoccupation
# preoccupation-,
# ,-or
# or-a
# a-hostile
# hostile-levity
# levity-when
# when-I
# I-realized
# realized-by
# by-some
# some-unmistakable
# unmistakable-sign
# sign-that
# that-an
# an-intimate
# intimate-revelation
# revelation-was
# was-quivering
# quivering-on
# on-the
# the-horizon
# horizon---
# ---for
# for-the
# the-intimate
# intimate-revelations
# revelations-of
# of-young
# young-men
# men-or
# or-at
# at-least
# least-the
# the-terms
# terms-in
# in-which
# which-they
# they-express
# express-them
# them-are
# are-usually
# usually-plagiaristic
# plagiaristic-and
# and-marred
# marred-by
# by-obvious
# obvious-suppressions
# suppressions-.
# .-Reserving
# Reserving-judgments
# judgments-is
# is-a
# a-matter
# matter-of
# of-infinite
# infinite-hope
# hope-.
# .-I
# I-am
# am-still
# still-a
# a-little
# little-afraid
# afraid-of
# of-missing
# missing-something
# something-if
# if-I
# I-forget
# forget-that
# that-,
# ,-as
# as-my
# my-father
# father-snobbishly
# snobbishly-suggested
# suggested-,
# ,-and
# and-I
# I-snobbishly
# snobbishly-repeat
# repeat-a
# a-sense
# sense-of
# of-the
# the-fundamental
# fundamental-decencies
# decencies-is
# is-parcelled
# parcelled-out
# out-unequally
# unequally-at
# at-birth
# birth-.
# .-And
# And-,
# ,-after
# after-boasting
# boasting-this
# this-way
# way-of
# of-my
# my-tolerance
# tolerance-,
# ,-I
# I-come
# come-to
# to-the
# the-admission
# admission-that
# that-it
# it-has
# has-a
# a-limit
# limit-.
# .-Conduct
# Conduct-may
# may-be
# be-founded
# founded-on
# on-the
# the-hard
# hard-rock
# rock-or
# or-the
# the-wet
# wet-marshes
# marshes-but
# but-after
# after-a
# a-certain
# certain-point
# point-I
# I-do
# do-n't
# n't-care
# care-what
# what-it
# it-'s
# 's-founded
# founded-on
# on-.
# .-When
# When-I
# I-came
# came-back
# back-from
# from-the
# the-East
# East-last
# last-autumn
# autumn-I
# I-felt
# felt-that
# that-I
# I-wanted
# wanted-the
# the-world
# world-to
# to-be
# be-in
# in-uniform
# uniform-and
# and-at
# at-a
# a-sort
# sort-of
# of-moral
# moral-attention
# attention-forever
# forever-;
# ;-I
# I-wanted
# wanted-no
# no-more
# more-riotous
# riotous-excursions
# excursions-with
# with-privileged
# privileged-glimpses
# glimpses-into
# into-the
# the-human
# human-heart
# heart-.
# .-Only
# Only-Gatsby
# Gatsby-,
# ,-the
# the-man
# man-who
# who-gives
# gives-his
# his-name
# name-to
# to-this
# this-book
# book-,
# ,-was
# was-exempt
# exempt-from
# from-my
# my-reaction
# reaction---
# ---Gatsby
# Gatsby-who
# who-represented
# represented-everything
# everything-for
# for-which
# which-I
# I-have
# have-an
# an-unaffected
# unaffected-scorn
# scorn-.
# .-If
# If-personality
# personality-is
# is-an
# an-unbroken
# unbroken-series
# series-of
# of-successful
# successful-gestures
# gestures-,
# ,-then
# then-there
# there-was
# was-something
# something-gorgeous
# gorgeous-about
# about-him
# him-,
# ,-some
# some-heightened
# heightened-sensitivity
# sensitivity-to
# to-the
# the-promises
# promises-of
# of-life
# life-,
# ,-as
# as-if
# if-he
# he-were
# were-related
# related-to
# to-one
# one-of
# of-those
# those-intricate
# intricate-machines
# machines-that
# that-register
# register-earthquakes
# earthquakes-ten
# ten-thousand
# thousand-miles
# miles-away
# away-.
# .-This
# This-responsiveness
# responsiveness-had
# had-nothing
# nothing-to
# to-do
# do-with
# with-that
# that-flabby
# flabby-impressionability
# impressionability-which
# which-is
# is-dignified
# dignified-under
# under-the
# the-name
# name-of
# of-the
# the-"
# "-creative
# creative-temperament
# temperament-"--
# "---it
# it-was
# was-an
# an-extraordinary
# extraordinary-gift
# gift-for
# for-hope
# hope-,
# ,-a
# a-romantic
# romantic-readiness
# readiness-such
# such-as
# as-I
# I-have
# have-never
# never-found
# found-in
# in-any
# any-other
# other-person
# person-and
# and-which
# which-it
# it-is
# is-not
# not-likely
# likely-I
# I-shall
# shall-ever
# ever-find
# find-again
# again-.
# .-No
# No---
# ---Gatsby
# Gatsby-turned
# turned-out
# out-all
# all-right
# right-at
# at-the
# the-end
# end-;
# ;-it
# it-is
# is-what
# what-preyed
# preyed-on
# on-Gatsby
# Gatsby-,
# ,-what
# what-foul
# foul-dust
# dust-floated
# floated-in
# in-the
# the-wake
# wake-of
# of-his
# his-dreams
# dreams-that
# that-temporarily
# temporarily-closed
# closed-out
# out-my
# my-interest
# interest-in
# in-the
# the-abortive
# abortive-sorrows
# sorrows-and
# and-short
# short--
# --winded
# winded-elations
# elations-of
# of-men
# men-.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-2b51df89df79> in <module>()
#       1 for i, word in enumerate(gatsby):
# ----> 2     print(str(word)+'-'+str(gatsby[i+1]))
#
# doc.pyx in spacy.tokens.doc.Doc.__getitem__()
#
# token.pxd in spacy.tokens.token.Token.cinit()
#
# IndexError: [E040] Attempt to access token at 554, max length 554.

# %%
# Running TextRank
nx_words = nx.from_numpy_matrix(adjacency.as_matrix())
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(bigrams)),
                reverse=True)
print(ranked[:5])
# Out:
# C:\Users\Loren\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(0.03501058397382176, 'riotous-excursions'), (0.0348320370392147, 'wet-marshes'), (0.0348320370392147, 'unmistakable-sign'), (0.0348320370392147, 'unbroken-series'), (0.0348320370392147, 'extraordinary-gift')]

# %% [markdown]
# # Trying bigrams with broader neighbor search

# %%
gatsby_filt = [word for word in gatsby if word.is_stop==False and (word.pos_=='NOUN' or word.pos_=='ADJ')]

# build bigrams from gatsby_filt
bigrams = set()
prev_word = gatsby_filt[0]
for i in range (1,len(gatsby_filt)):
    bigrams.add(str(prev_word)+"-"+str(gatsby_filt[i]))
    prev_word = gatsby_filt[i]
  

  
adjacency=pd.DataFrame(columns=bigrams,index=bigrams,data=0)

# %%
# Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby):
    if i == 553:
        break
    bigram = str(word)+'-'+str(gatsby[i+1])
    # Checking if any of the word's next four neighbors are in the word list 
    if any([bigram == item for item in bigrams]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby)-(len(gatsby)-(i+20)))
        # The potential neighbors.
        nextwords=gatsby[i+1:end]
        # Filtering the neighbors to select only those in the word list
        nextgrams = []
        prev_word = nextwords[0]
        for i in range (1,len(nextwords)):
            nextgrams.append(str(prev_word)+"-"+str(nextwords[i]))
            prev_word = nextwords[i]
        
        
        inset=[x in bigrams for x in nextgrams]
        neighbors=[nextgrams[i] for i in range(len(nextgrams)) if inset[i]]
        #print(nextgrams, inset, neighbors)
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            #Access a group of rows and columns by label(s) or a boolean array. 
            adjacency.loc[bigram,neighbors]=adjacency.loc[bigram,neighbors]+1

# %%
# Running TextRank
nx_words = nx.from_numpy_matrix(adjacency.as_matrix())
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(bigrams)),
                reverse=True)
print(ranked[:5])
# Out:
# C:\Users\Loren\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(0.030122012696693984, 'abnormal-mind'), (0.02590442862449952, 'flabby-impressionability'), (0.02464874783786393, 'extraordinary-gift'), (0.02464874783786393, 'creative-temperament'), (0.02426771217836155, 'obvious-suppressions')]

# %% [markdown]
# # Trigrams

# %%
import string
exclude = set(string.punctuation)

gatsby_filt = [word for word in gatsby if word.is_stop==False and word not in exclude and (word.pos_=='NOUN' or word.pos_=='ADJ')]

# build bigrams from gatsby_filt
bigrams = set()
prev_word = gatsby_filt[0]
for i in range (1,len(gatsby_filt)-1):
    bigrams.add(str(prev_word)+"-"+str(gatsby_filt[i])+'-'+str(gatsby_filt[i+1]))
    prev_word = gatsby_filt[i]
  

  
adjacency=pd.DataFrame(columns=bigrams,index=bigrams,data=0)

# %%
adjacency.head()
# Out:
#                           levity-unmistakable-sign  person-likely-end  \
# levity-unmistakable-sign                         0                  0
# person-likely-end                                0                  0
# quality-normal-person                            0                  0
# habit-curious-natures                            0                  0
# rock-wet-marshes                                 0                  0
#
#                           quality-normal-person  habit-curious-natures  \
# levity-unmistakable-sign                      0                      0
# person-likely-end                             0                      0
# quality-normal-person                         0                      0
# habit-curious-natures                         0                      0
# rock-wet-marshes                              0                      0
#
#                           rock-wet-marshes  riotous-excursions-privileged  \
# levity-unmistakable-sign                 0                              0
# person-likely-end                        0                              0
# quality-normal-person                    0                              0
# habit-curious-natures                    0                              0
# rock-wet-marshes                         0                              0
#
#                           decencies-birth-way  life-intricate-machines  \
# levity-unmistakable-sign                    0                        0
# person-likely-end                           0                        0
# quality-normal-person                       0                        0
# habit-curious-natures                       0                        0
# rock-wet-marshes                            0                        0
#
#                           matter-infinite-hope  admission-limit-Conduct  \
# levity-unmistakable-sign                     0                        0
# person-likely-end                            0                        0
# quality-normal-person                        0                        0
# habit-curious-natures                        0                        0
# rock-wet-marshes                             0                        0
#
#                                       ...               \
# levity-unmistakable-sign              ...
# person-likely-end                     ...
# quality-normal-person                 ...
# habit-curious-natures                 ...
# rock-wet-marshes                      ...
#
#                           vulnerable-years-father  \
# levity-unmistakable-sign                        0
# person-likely-end                               0
# quality-normal-person                           0
# habit-curious-natures                           0
# rock-wet-marshes                                0
#
#                           impressionability-dignified-creative  \
# levity-unmistakable-sign                                     0
# person-likely-end                                            0
# quality-normal-person                                        0
# habit-curious-natures                                        0
# rock-wet-marshes                                             0
#
#                           hope-little-afraid  sensitivity-promises-life  \
# levity-unmistakable-sign                   0                          0
# person-likely-end                          0                          0
# quality-normal-person                      0                          0
# habit-curious-natures                      0                          0
# rock-wet-marshes                           0                          0
#
#                           Reserving-judgments-matter  marshes-certain-point  \
# levity-unmistakable-sign                           0                      0
# person-likely-end                                  0                      0
# quality-normal-person                              0                      0
# habit-curious-natures                              0                      0
# rock-wet-marshes                                   0                      0
#
#                           tolerance-admission-limit  dust-wake-dreams  \
# levity-unmistakable-sign                          0                 0
# person-likely-end                                 0                 0
# quality-normal-person                             0                 0
# habit-curious-natures                             0                 0
# rock-wet-marshes                                  0                 0
#
#                           point-autumn-world  attention-riotous-excursions
# levity-unmistakable-sign                   0                             0
# person-likely-end                          0                             0
# quality-normal-person                      0                             0
# habit-curious-natures                      0                             0
# rock-wet-marshes                           0                             0
#
# [5 rows x 131 columns]

# %%
# Iterating through each word in the text and indicating which of the unique words are its neighbors
for i,word in enumerate(gatsby):
    if i == 552:
        break
    bigram = str(word)+'-'+str(gatsby[i+1])+'-'+str(gatsby[i+2])
    # Checking if any of the word's next four neighbors are in the word list 
    if any([bigram == item for item in bigrams]):
        # Making sure to stop at the end of the string, even if there are less than four words left after the target.
        end=max(0,len(gatsby)-(len(gatsby)-(i+20)))
        # The potential neighbors.
        nextwords=gatsby[i+1:end]
        # Filtering the neighbors to select only those in the word list
        nextgrams = []
        prev_word = nextwords[0]
        for i in range (1,len(nextwords)-1):
            nextgrams.append(str(prev_word)+"-"+str(nextwords[i])+'-'+str(nextwords[i+1]))
            prev_word = nextwords[i]
        
        
        inset=[x in bigrams for x in nextgrams]
        neighbors=[nextgrams[i] for i in range(len(nextgrams)) if inset[i]]
        #print(nextgrams, inset, neighbors)
        # Adding 1 to the adjacency matrix for neighbors of the target word
        if neighbors:
            #Access a group of rows and columns by label(s) or a boolean array. 
            adjacency.loc[bigram,neighbors]=adjacency.loc[bigram,neighbors]+1

# %%
# Running TextRank
nx_words = nx.from_numpy_matrix(adjacency.as_matrix())
ranks=nx.pagerank(nx_words, alpha=.85, tol=.00000001)

# Identifying the five most highly ranked keywords
ranked = sorted(((ranks[i],s) for i,s in enumerate(bigrams)),
                reverse=True)
print(ranked[:5])
# Out:
# C:\Users\Loren\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(0.0076335877862595495, 'younger-vulnerable-years'), (0.0076335877862595495, 'young-men-terms'), (0.0076335877862595495, 'years-father-advice'), (0.0076335877862595495, 'world-uniform-sort'), (0.0076335877862595495, 'world-advantages-communicative')]
